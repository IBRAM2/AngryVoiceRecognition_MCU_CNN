# %%
import numpy as np
from numpy import array
from numpy import savetxt
import math
from scipy.fft import dct
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_curve, auc, roc_auc_score
import seaborn as sns
import IPython.display as ipd
import librosa
import tensorflow as tf
from tensorflow.keras.regularizers import l2
import pathlib

# %% [markdown]
# ### Carga Audios

# %%
#Parámetros
sampling_rate = 4096
duration = 2

#Calcula número de muestras
num_muestras = sampling_rate*duration
num_muestras

#Vector de clases
clases_vec = [0,1]
emotion_vec = ["Other","Angry"]

# %%
#Carga Audios Entrenamiento (English)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
trainAudioAngryPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Angry/train'
#Carpeta con los audios de felicidad (Happy)
trainAudioHappyPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Happy/train'
#Carpeta con los audios neutrales (Neutral)
trainAudioNeutralPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Neutral/train'
#Carpeta con los audios de tristeza (Sad)
trainAudioSadPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Sad/train'
#Carpeta con los audios de tristeza (Surprise)
trainAudioSurprisePath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Surprise/train'
#Carga Audios Prueba (English)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
testAudioAngryPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Angry/test'
#Carpeta con los audios de felicidad (Happy)
testAudioHappyPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Happy/test'
#Carpeta con los audios neutrales (Neutral)
testAudioNeutralPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Neutral/test'
#Carpeta con los audios de tristeza (Sad)
testAudioSadPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Sad/test'
#Carpeta con los audios de tristeza (Surprise)
testAudioSurprisePath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Surprise/test'
#Carga Audios Evaluación (English)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
evalAudioAngryPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Angry/evaluation'
#Carpeta con los audios de felicidad (Happy)
evalAudioHappyPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Happy/evaluation'
#Carpeta con los audios neutrales (Neutral)
evalAudioNeutralPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Neutral/evaluation'
#Carpeta con los audios de tristeza (Sad)
evalAudioSadPath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Sad/evaluation'
#Carpeta con los audios de tristeza (Surprise)
evalAudioSurprisePath = '../Dataset/ESD/Emotional_Speech_Dataset/English/Surprise/evaluation'



#Carga Audios Entrenamiento (Chinese)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
trainAudioAngryPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Angry/train'
#Carpeta con los audios de felicidad (Happy)
trainAudioHappyPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Happy/train'
#Carpeta con los audios neutrales (Neutral)
trainAudioNeutralPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Neutral/train'
#Carpeta con los audios de tristeza (Sad)
trainAudioSadPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Sad/train'
#Carpeta con los audios de tristeza (Surprise)
trainAudioSurprisePathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Surprise/train'
#Carga Audios Prueba (Chinese)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
testAudioAngryPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Angry/test'
#Carpeta con los audios de felicidad (Happy)
testAudioHappyPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Happy/test'
#Carpeta con los audios neutrales (Neutral)
testAudioNeutralPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Neutral/test'
#Carpeta con los audios de tristeza (Sad)
testAudioSadPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Sad/test'
#Carpeta con los audios de tristeza (Surprise)
testAudioSurprisePathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Surprise/test'
#Carga Audios Evaluación (Chinese)
#---------------------------------------------------------
#Carpeta con los audios de enojo (Angry)
evalAudioAngryPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Angry/evaluation'
#Carpeta con los audios de felicidad (Happy)
evalAudioHappyPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Happy/evaluation'
#Carpeta con los audios neutrales (Neutral)
evalAudioNeutralPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Neutral/evaluation'
#Carpeta con los audios de tristeza (Sad)
evalAudioSadPathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Sad/evaluation'
#Carpeta con los audios de tristeza (Surprise)
evalAudioSurprisePathC = '../Dataset/ESD/Emotional_Speech_Dataset/Chinese/Surprise/evaluation'

# %%
#Función para cargar audios de una carpeta
def loadAudio(pathAudio, label):
    #Encuentra los archivos con extensión .wav y los pone en una lista
    files = librosa.util.find_files(pathAudio, ext=['wav']) 
    #Convierte la lista en un arreglo numpy
    files = np.asarray(files)

    #Crea lista de audios vacía
    Audios = []

    #Lee los audios y los almacena en la lista de audios
    for archivo in files: 
        audio = librosa.load(archivo, sr=sampling_rate, mono=True, duration=duration)
        #calcula espectrograma
        spectrogram = np.abs(librosa.stft(audio[0], n_fft=512, hop_length=256))
        #calcula espectrograma en decibeles 
        spectrogram_db = librosa.amplitude_to_db(spectrogram, ref=np.max)
        
        #Calcula la energía máxima por columna de tiempo
        max_energy = np.empty(spectrogram_db.shape[1])
        for i in range(spectrogram_db.shape[1]):
            max_energy[i] = np.mean(spectrogram_db[:,i])
            
        #Guarda posición inicial de dato de muestro
        for i in range(1, spectrogram_db.shape[1]):
            diff_energy = abs(max_energy[i]-max_energy[i-1])
            if(diff_energy >= 5):
                #Número de columnas
                col = spectrogram_db.shape[1]
                #Muestras por columna
                muesXcol = int(num_muestras/col)
                #Posición inicial
                start_pos = (i * muesXcol)
                break
        
        #Lee audio nuevamente pero agregando 2 segundos
        audio = librosa.load(archivo, sr=sampling_rate, mono=True, duration=duration+2)     
        #Toma 2 segundos de audio a partir de donde empieza el sonido
        new_audio = audio[0][start_pos : start_pos+num_muestras]
        
        Audios.append(new_audio)
    
    #Crea nueva lista de audios con igual dimensiones
    Audios_equal_dim = []
    
    for audio in Audios:
        
        if audio.shape[0]<num_muestras:
            sample = np.append(audio,np.zeros(num_muestras-audio.shape[0]))
        else:
            sample = audio[0:num_muestras]
        
        #Calcula media y desviación estandar
        mean = np.mean(sample)
        sd = np.std(sample)
        #Calcula ruido blanco
        white_noise = np.random.normal(loc = mean, scale = abs(sd/50), size = num_muestras)
        
        #Concatena audio más ruido
        Audios_equal_dim.append(sample+white_noise)
            
    #Regresa audios
    return np.asarray(Audios_equal_dim), np.full(len(Audios), label)

# %%
#Carga Audios Entrenamiento
#---------------------------------------------------------
trainAudiosAngry, trainLabelAngry = loadAudio(trainAudioAngryPath, clases_vec[1])
trainAudiosAngryC, trainLabelAngryC = loadAudio(trainAudioAngryPathC, clases_vec[1])

trainAudiosHappy, trainLabelHappy = loadAudio(trainAudioHappyPath, clases_vec[0])
trainAudiosHappyC, trainLabelHappyC = loadAudio(trainAudioHappyPathC, clases_vec[0])
trainAudiosNeutral, trainLabelNeutral = loadAudio(trainAudioNeutralPath, clases_vec[0])
trainAudiosNeutralC, trainLabelNeutralC = loadAudio(trainAudioNeutralPathC, clases_vec[0])
trainAudiosSad, trainLabelSad = loadAudio(trainAudioSadPath, clases_vec[0])
trainAudiosSadC, trainLabelSadC = loadAudio(trainAudioSadPathC, clases_vec[0])
trainAudiosSurprise, trainLabelSurprise = loadAudio(trainAudioSurprisePath, clases_vec[0])
trainAudiosSurpriseC, trainLabelSurpriseC = loadAudio(trainAudioSurprisePathC, clases_vec[0])

#Carga Audios Prueba
#---------------------------------------------------------
testAudiosAngry, testLabelAngry = loadAudio(testAudioAngryPath, clases_vec[1])
testAudiosAngryC, testLabelAngryC = loadAudio(testAudioAngryPathC, clases_vec[1])

testAudiosHappy, testLabelHappy = loadAudio(testAudioHappyPath, clases_vec[0])
testAudiosHappyC, testLabelHappyC = loadAudio(testAudioHappyPathC, clases_vec[0])
testAudiosNeutral, testLabelNeutral = loadAudio(testAudioNeutralPath, clases_vec[0])
testAudiosNeutralC, testLabelNeutralC = loadAudio(testAudioNeutralPathC, clases_vec[0])
testAudiosSad, testLabelSad = loadAudio(testAudioSadPath, clases_vec[0])
testAudiosSadC, testLabelSadC = loadAudio(testAudioSadPathC, clases_vec[0])
testAudiosSurprise, testLabelSurprise = loadAudio(testAudioSurprisePath, clases_vec[0])
testAudiosSurpriseC, testLabelSurpriseC = loadAudio(testAudioSurprisePathC, clases_vec[0])

#Carga Audios Evaluación
#---------------------------------------------------------
evalAudiosAngry, evalLabelAngry = loadAudio(evalAudioAngryPath, clases_vec[1])
evalAudiosAngryC, evalLabelAngryC = loadAudio(evalAudioAngryPathC, clases_vec[1])

evalAudiosHappy, evalLabelHappy = loadAudio(evalAudioHappyPath, clases_vec[0])
evalAudiosHappyC, evalLabelHappyC = loadAudio(evalAudioHappyPathC, clases_vec[0])
evalAudiosNeutral, evalLabelNeutral = loadAudio(evalAudioNeutralPath, clases_vec[0])
evalAudiosNeutralC, evalLabelNeutralC = loadAudio(evalAudioNeutralPathC, clases_vec[0])
evalAudiosSad, evalLabelSad = loadAudio(evalAudioSadPath, clases_vec[0])
evalAudiosSadC, evalLabelSadC = loadAudio(evalAudioSadPathC, clases_vec[0])
evalAudiosSurprise, evalLabelSurprise = loadAudio(evalAudioSurprisePath, clases_vec[0])
evalAudiosSurpriseC, evalLabelSurpriseC = loadAudio(evalAudioSurprisePathC, clases_vec[0])

# %%
#Resumen de datos de entrenamiento
#---------------------------------------------------------
print('Audios de entrenamiento:')
print('Número de audios de enojo:\t', trainAudiosAngry.shape, "Etiqueta: ", trainLabelAngry[0])
print('Número de audios de enojoC:\t', trainAudiosAngryC.shape, "Etiqueta: ", trainLabelAngryC[0])
print('Total audios enojo: ',trainAudiosAngry.shape[0]+trainAudiosAngryC.shape[0])
print("\n")
print('Número de audios de felicidad:\t', trainAudiosHappy.shape, "Etiqueta: ", trainLabelHappy[0])
print('Número de audios de felicidadC:\t', trainAudiosHappyC.shape, "Etiqueta: ", trainLabelHappyC[0])
print('Número de audios neutrales:\t', trainAudiosNeutral.shape, "Etiqueta: ", trainLabelNeutral[0])
print('Número de audios neutralesC:\t', trainAudiosNeutralC.shape, "Etiqueta: ", trainLabelNeutralC[0])
print('Número de audios de tristeza:\t', trainAudiosSad.shape, "Etiqueta: ", trainLabelSad[0])
print('Número de audios de tristezaC:\t', trainAudiosSadC.shape, "Etiqueta: ", trainLabelSadC[0])
print('Número de audios de sorpresa:\t', trainAudiosSurprise.shape, "Etiqueta: ", trainLabelSurprise[0])
print('Número de audios de sorpresaC:\t', trainAudiosSurpriseC.shape, "Etiqueta: ", trainLabelSurpriseC[0])
#Resumen de datos de entrenamiento
#---------------------------------------------------------
print('\nAudios de prueba:')
print('Número de audios de enojo:\t', testAudiosAngry.shape, "Etiqueta: ", testLabelAngry[0])
print('Número de audios de enojoC:\t', testAudiosAngryC.shape, "Etiqueta: ", testLabelAngryC[0])
print('Total audios enojo: ',testAudiosAngry.shape[0]+testAudiosAngryC.shape[0])
print("\n")
print('Número de audios de felicidad:\t', testAudiosHappy.shape, "Etiqueta: ", testLabelHappy[0])
print('Número de audios de felicidadC:\t', testAudiosHappyC.shape, "Etiqueta: ", testLabelHappyC[0])
print('Número de audios neutrales:\t', testAudiosNeutral.shape, "Etiqueta: ", testLabelNeutral[0])
print('Número de audios neutralesC:\t', testAudiosNeutralC.shape, "Etiqueta: ", testLabelNeutralC[0])
print('Número de audios de tristeza:\t', testAudiosSad.shape, "Etiqueta: ", testLabelSad[0])
print('Número de audios de tristezaC:\t', testAudiosSadC.shape, "Etiqueta: ", testLabelSadC[0])
print('Número de audios de sorpresa:\t', testAudiosSurprise.shape, "Etiqueta: ", testLabelSurprise[0])
print('Número de audios de sorpresaC:\t', testAudiosSurpriseC.shape, "Etiqueta: ", testLabelSurpriseC[0])

#Resumen de datos de entrenamiento
#---------------------------------------------------------
print('\nAudios de evaluación:')
print('Número de audios de enojo:\t', evalAudiosAngry.shape, "Etiqueta: ", evalLabelAngry[0])
print('Número de audios de enojoC:\t', evalAudiosAngryC.shape, "Etiqueta: ", evalLabelAngryC[0])
print('Total audios enojo: ',evalAudiosAngry.shape[0]+evalAudiosAngryC.shape[0])
print("\n")
print('Número de audios de felicidad:\t', evalAudiosHappy.shape, "Etiqueta: ", evalLabelHappy[0])
print('Número de audios de felicidadC:\t', evalAudiosHappyC.shape, "Etiqueta: ", evalLabelHappyC[0])
print('Número de audios neutrales:\t', evalAudiosNeutral.shape, "Etiqueta: ", evalLabelNeutral[0])
print('Número de audios neutralesC:\t', evalAudiosNeutralC.shape, "Etiqueta: ", evalLabelNeutralC[0])
print('Número de audios de tristeza:\t', evalAudiosSad.shape, "Etiqueta: ", evalLabelSad[0])
print('Número de audios de tristezaC:\t', evalAudiosSadC.shape, "Etiqueta: ", evalLabelSadC[0])
print('Número de audios de sorpresa:\t', evalAudiosSurprise.shape, "Etiqueta: ", evalLabelSurprise[0])
print('Número de audios de sorpresaC:\t', evalAudiosSurpriseC.shape, "Etiqueta: ", evalLabelSurpriseC[0])
# Out:
# Audios de entrenamiento:
# Número de audios de enojo:	 (3000, 8192) Etiqueta:  1
# Número de audios de enojoC:	 (3000, 8192) Etiqueta:  1
# Total audios enojo:  6000
#
#
# Número de audios de felicidad:	 (3000, 8192) Etiqueta:  0
# Número de audios de felicidadC:	 (3000, 8192) Etiqueta:  0
# Número de audios neutrales:	 (3000, 8192) Etiqueta:  0
# Número de audios neutralesC:	 (3000, 8192) Etiqueta:  0
# Número de audios de tristeza:	 (3000, 8192) Etiqueta:  0
# Número de audios de tristezaC:	 (3000, 8192) Etiqueta:  0
# Número de audios de sorpresa:	 (3000, 8192) Etiqueta:  0
# Número de audios de sorpresaC:	 (3000, 8192) Etiqueta:  0
#
# Audios de prueba:
# Número de audios de enojo:	 (300, 8192) Etiqueta:  1
# Número de audios de enojoC:	 (300, 8192) Etiqueta:  1
# Total audios enojo:  600
#
#
# Número de audios de felicidad:	 (300, 8192) Etiqueta:  0
# Número de audios de felicidadC:	 (300, 8192) Etiqueta:  0
# Número de audios neutrales:	 (300, 8192) Etiqueta:  0
# Número de audios neutralesC:	 (300, 8192) Etiqueta:  0
# Número de audios de tristeza:	 (300, 8192) Etiqueta:  0
# Número de audios de tristezaC:	 (300, 8192) Etiqueta:  0
# Número de audios de sorpresa:	 (300, 8192) Etiqueta:  0
# Número de audios de sorpresaC:	 (300, 8192) Etiqueta:  0
#
# Audios de evaluación:
# Número de audios de enojo:	 (200, 8192) Etiqueta:  1
# Número de audios de enojoC:	 (200, 8192) Etiqueta:  1
# Total audios enojo:  400
#
#
# Número de audios de felicidad:	 (200, 8192) Etiqueta:  0
# Número de audios de felicidadC:	 (200, 8192) Etiqueta:  0
# Número de audios neutrales:	 (200, 8192) Etiqueta:  0
# Número de audios neutralesC:	 (200, 8192) Etiqueta:  0
# Número de audios de tristeza:	 (200, 8192) Etiqueta:  0
# Número de audios de tristezaC:	 (200, 8192) Etiqueta:  0
# Número de audios de sorpresa:	 (200, 8192) Etiqueta:  0
# Número de audios de sorpresaC:	 (200, 8192) Etiqueta:  0

# %% [markdown]
# ### Prepara audios y etiquetas

# %%
#Función para elegir cierto número de muestras de audio y etiquetas aleatoriamente
def random_samples(num_index, num_total, audios, labels):
    random_index = np.random.choice(num_index, num_total//8, replace=False)
    random_audios = audios[random_index]
    random_labels = labels[random_index]
    return random_audios, random_labels

# %%
#Numero total de audios de enojo en entrenamiento, prueba y evaluación 
num_aud_angry_train = trainAudiosAngry.shape[0]+trainAudiosAngryC.shape[0]
num_aud_angry_test = testAudiosAngry.shape[0]+testAudiosAngryC.shape[0]
num_aud_angry_eval = evalAudiosAngry.shape[0]+evalAudiosAngryC.shape[0]

#Toma aleatoriamente "num_audios_angry_train" muestras para cada emoción distinta al enojo
trainAudiosHappy, trainLabelHappy = random_samples(trainAudiosHappy.shape[0], num_aud_angry_train, trainAudiosHappy, trainLabelHappy)
trainAudiosHappyC, trainLabelHappyC = random_samples(trainAudiosHappyC.shape[0], num_aud_angry_train, trainAudiosHappyC, trainLabelHappyC)
trainAudiosNeutral, trainLabelNeutral = random_samples(trainAudiosNeutral.shape[0], num_aud_angry_train, trainAudiosNeutral, trainLabelNeutral)
trainAudiosNeutralC, trainLabelNeutralC = random_samples(trainAudiosNeutralC.shape[0], num_aud_angry_train, trainAudiosNeutralC, trainLabelNeutralC)
trainAudiosSad, trainLabelSad = random_samples(trainAudiosSad.shape[0], num_aud_angry_train, trainAudiosSad, trainLabelSad)
trainAudiosSadC, trainLabelSadC = random_samples(trainAudiosSadC.shape[0], num_aud_angry_train, trainAudiosSadC, trainLabelSadC)
trainAudiosSurprise, trainLabelSurprise = random_samples(trainAudiosSurprise.shape[0], num_aud_angry_train, trainAudiosSurprise, trainLabelSurprise)
trainAudiosSurpriseC, trainLabelSurpriseC = random_samples(trainAudiosSurpriseC.shape[0], num_aud_angry_train, trainAudiosSurpriseC, trainLabelSurpriseC)

#Toma aleatoriamente "num_audios_angry_test" muestras para cada emoción distinta al enojo
testAudiosHappy, testLabelHappy = random_samples(testAudiosHappy.shape[0], num_aud_angry_test, testAudiosHappy, testLabelHappy)
testAudiosHappyC, testLabelHappyC = random_samples(testAudiosHappyC.shape[0], num_aud_angry_test, testAudiosHappyC, testLabelHappyC)
testAudiosNeutral, testLabelNeutral = random_samples(testAudiosNeutral.shape[0], num_aud_angry_test, testAudiosNeutral, testLabelNeutral)
testAudiosNeutralC, testLabelNeutralC = random_samples(testAudiosNeutralC.shape[0], num_aud_angry_test, testAudiosNeutralC, testLabelNeutralC)
testAudiosSad, testLabelSad = random_samples(testAudiosSad.shape[0], num_aud_angry_test, testAudiosSad, testLabelSad)
testAudiosSadC, testLabelSadC = random_samples(testAudiosSadC.shape[0], num_aud_angry_test, testAudiosSadC, testLabelSadC)
testAudiosSurprise, testLabelSurprise = random_samples(testAudiosSurprise.shape[0], num_aud_angry_test, testAudiosSurprise, testLabelSurprise)
testAudiosSurpriseC, testLabelSurpriseC = random_samples(testAudiosSurpriseC.shape[0], num_aud_angry_test, testAudiosSurpriseC, testLabelSurpriseC)

#Toma aleatoriamente "num_audios_angry_eval" muestras para cada emoción distinta al enojo
evalAudiosHappy, evalLabelHappy = random_samples(evalAudiosHappy.shape[0], num_aud_angry_eval, evalAudiosHappy, evalLabelHappy)
evalAudiosHappyC, evalLabelHappyC = random_samples(evalAudiosHappyC.shape[0], num_aud_angry_eval, evalAudiosHappyC, evalLabelHappyC)
evalAudiosNeutral, evalLabelNeutral = random_samples(evalAudiosNeutral.shape[0], num_aud_angry_eval, evalAudiosNeutral, evalLabelNeutral)
evalAudiosNeutralC, evalLabelNeutralC = random_samples(evalAudiosNeutralC.shape[0], num_aud_angry_eval, evalAudiosNeutralC, evalLabelNeutralC)
evalAudiosSad, evalLabelSad = random_samples(evalAudiosSad.shape[0], num_aud_angry_eval, evalAudiosSad, evalLabelSad)
evalAudiosSadC, evalLabelSadC = random_samples(evalAudiosSadC.shape[0], num_aud_angry_eval, evalAudiosSadC, evalLabelSadC)
evalAudiosSurprise, evalLabelSurprise = random_samples(evalAudiosSurprise.shape[0], num_aud_angry_eval, evalAudiosSurprise, evalLabelSurprise)
evalAudiosSurpriseC, evalLabelSurpriseC = random_samples(evalAudiosSurpriseC.shape[0], num_aud_angry_eval, evalAudiosSurpriseC, evalLabelSurpriseC)

# %%
#Función para concatenar audios y etiquetas
def concatenaAudios(audio1, audio2, label1, label2):
    audio1 = np.concatenate([audio1, audio2])
    label1 = np.concatenate([label1, label2])
    return audio1, label1

# %%
#Concatena audios y etiquetas de entrenamiento
#---------------------------------------------------------
trainAudios, trainLabels = concatenaAudios(trainAudiosAngry, trainAudiosAngryC, trainLabelAngry, trainLabelAngryC)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosHappy, trainLabels, trainLabelHappy)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosHappyC, trainLabels, trainLabelHappyC)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosNeutral, trainLabels, trainLabelNeutral)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosNeutralC, trainLabels, trainLabelNeutralC)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosSad, trainLabels, trainLabelSad)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosSadC, trainLabels, trainLabelSadC)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosSurprise, trainLabels, trainLabelSurprise)
trainAudios, trainLabels = concatenaAudios(trainAudios, trainAudiosSurpriseC, trainLabels, trainLabelSurpriseC)

#Concatena audios y etiquetas de prueba
#---------------------------------------------------------
testAudios, testLabels = concatenaAudios(testAudiosAngry, testAudiosAngryC, testLabelAngry, testLabelAngryC)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosHappy, testLabels, testLabelHappy)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosHappyC, testLabels, testLabelHappyC)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosNeutral, testLabels, testLabelNeutral)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosNeutralC, testLabels, testLabelNeutralC)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosSad, testLabels, testLabelSad)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosSadC, testLabels, testLabelSadC)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosSurprise, testLabels, testLabelSurprise)
testAudios, testLabels = concatenaAudios(testAudios, testAudiosSurpriseC, testLabels, testLabelSurpriseC)

#Concatena audios y etiquetas de evaluación
#---------------------------------------------------------
evalAudios, evalLabels = concatenaAudios(evalAudiosAngry, evalAudiosAngryC, evalLabelAngry, evalLabelAngryC)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosHappy, evalLabels, evalLabelHappy)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosHappyC, evalLabels, evalLabelHappyC)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosNeutral, evalLabels, evalLabelNeutral)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosNeutralC, evalLabels, evalLabelNeutralC)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosSad, evalLabels, evalLabelSad)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosSadC, evalLabels, evalLabelSadC)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosSurprise, evalLabels, evalLabelSurprise)
evalAudios, evalLabels = concatenaAudios(evalAudios, evalAudiosSurpriseC, evalLabels, evalLabelSurpriseC)

# %%
#Resumen de audios
print('Número de audios de entrenamiento: ', trainAudios.shape, "Número de etiquetaa: ", trainLabels.shape)
print('Número de audios de prueba: ', testAudios.shape, "Número de etiqueta: ", testLabels.shape)
print('Número de audios evaluación: ', evalAudios.shape, "Número de etiqueta: ", evalLabels.shape)
# Out:
# Número de audios de entrenamiento:  (12000, 8192) Número de etiquetaa:  (12000,)
# Número de audios de prueba:  (1200, 8192) Número de etiqueta:  (1200,)
# Número de audios evaluación:  (800, 8192) Número de etiqueta:  (800,)

# %%
#Prueba
num_audio = 5
#Grafica la señal de primer audio
plt.figure(figsize=(14, 5))
plt.plot(trainAudios[num_audio])
plt.title("Señal de audio", {'fontsize':20, 'fontweight':'bold'})
plt.show()
#Reproduce audio
ipd.Audio(trainAudios[num_audio], rate= sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Calcula MFCCs

# %%
#Parámetros para calcular espectrograma
#-------------------------------------
#Cantidad de datos por audio
Size_data = num_muestras
#Tamaño de la ventana
Size_win = 256
#Tamaño de offset
Size_off = 128
#Número total de ventaneos
total_win_num = int(((Size_data-Size_win)/Size_off)+1)
total_win_num

#Parámetros para calcular MFCCs
#------------------------------
#Frecuencia mínima y máxima
frec_min = 20
frec_max = sampling_rate/2
#numero de bandas de Mel
Mel_bands = 20

# %%
#Función para calcular un filtro triangular
def triangular_fun(lower_lim, medium_lim, upper_lim, points_num):
    #Crea vector de coeficientes
    coefficients = np.zeros(points_num)
    #Calcula coeficientes
    for j in range(points_num):
        
        if j>=lower_lim and j<=medium_lim:
            coefficients[j] = (j - lower_lim) / (medium_lim - lower_lim)
        elif j>medium_lim and j<=upper_lim:
            coefficients[j] = (upper_lim - j) / (upper_lim - medium_lim)
        else: 
            coefficients[j] = 0
    #Regresa coeficientes
    return coefficients

def triangular_filter_mat(frec_min, frec_max, Mel_bands):
    #numero de límites de bandas
    Mel_num_limits = Mel_bands+2
    #Frecuencia mínima y máxima en Mels
    frec_min_mel = 2595 * np.log10(1 + frec_min / 700)
    frec_max_mel = 2595 * np.log10(1 + frec_max / 700)
    #Tamaño de límite de separación de bandas en Mels
    separation_mel = (frec_max_mel-frec_min_mel)/(Mel_num_limits-1)
    
    #Crea vecor de límites de bandas mel
    mel_limits = np.zeros(Mel_num_limits)
    #Crea vector de límites equidistantes en Mels
    mel_limits[0] = frec_min_mel
    for i in range(1,Mel_num_limits):
        mel_limits[i] = mel_limits[i-1]+separation_mel
    
    #Crea vecor de límites de bandas en Hertz
    Hz_limits = np.zeros(Mel_num_limits)
    #Conversión de límites de Mel a Hertz
    for i in range(Mel_num_limits):
        Hz_limits[i] = 700 * (10**(mel_limits[i]/ 2595) - 1)
        
    #Crea vecor de límites de bandas en FFT bins
    FFT_bins = np.zeros(Mel_num_limits)
    #Cambia valores de frcuencia (Hertz) por valores al FFT bin más cercano, 
    for i in range(Mel_num_limits):
        FFT_bins[i] = math.floor((Size_win//2+1)*Hz_limits[i]/frec_max)
    FFT_bins[Mel_num_limits-1] = Size_win//2
    
    #Define matriz de filtros triangulares
    Trian_mat= np.zeros((Mel_bands, Size_win//2+1))
    #Calula banco de filtros tringulares
    for i in range(2,Mel_num_limits):
        trian_filter = triangular_fun(FFT_bins[i-2], FFT_bins[i-1], FFT_bins[i], Size_win//2+1)
        Trian_mat[i-2,:] = trian_filter
    
    return Trian_mat

#Preénfasis
def preemphasis(signal, coeff=0.97):
    return np.append(signal[0], signal[1:] - coeff * signal[:-1])

#Ventaneo
def windowing(Hamming_window, preemphasized_signal):
    #Define matriz de ventaneos
    Win_mat= np.zeros((Size_win, total_win_num))

    #Ciclo para realizar ventaneo
    cont = 0
    for i in range(total_win_num):
        for j in range(Size_win):
            Win_mat[j][i] = Hamming_window[j]*preemphasized_signal[cont]
            cont = cont+1
        cont = cont-(Size_win-Size_off)
    
    return Win_mat

#fft
def fft_mat(Win_mat):
    #Define matriz de espectrograma
    FFT_mat= np.zeros((1+Size_win//2, total_win_num))
    #Ciclo para realizar FFT por ventana
    for i in range(total_win_num):
        FFT = abs(np.fft.fft(Win_mat[:,i], n = Size_win))
        FFT_mat[:,i] = FFT[0:1+Size_win//2]
    
    return FFT_mat

#Crea ventana Hamming con tamaño Size_win
Hamming_window = np.zeros(Size_win)
for i in range(Size_win):
    Hamming_window[i] = 0.53836-0.46164*(np.cos((2*np.pi*i)/(Size_win-1)));

# %%
#Función para calcular MFCCs
def calculoMFCCs(Audios):
    
    number = 1 #Inicializa numero de imagen
    mfccs = [] #Inicializa lista vacía de mfccs
    
    #Caucula Filtros triangulares
    Trian_mat = triangular_filter_mat(frec_min, frec_max, Mel_bands) 
    
    #Ciclo for para calcular MFCCs de cada audio
    for audio in Audios:
        #Espectrograma
        #------------------------------------------------------------------------
        #Preénfasis
        preemphasized_signal = preemphasis(audio)
        #Ventaneo
        Win_mat = windowing(Hamming_window, preemphasized_signal)
        #Fast Fourier Transform (FFT)
        FFT_mat = fft_mat(Win_mat)
        #Aplica banco de filtros triangulares a espectrograma
        Mel_mat = np.dot(Trian_mat, FFT_mat)
        #Aplica transformación logarítmita para escala más adecuada
        Mel_mat_log = 13*np.log(Mel_mat)
        #Aplica transformada de coseno discreta (DCT)
        mfcc = dct(Mel_mat_log, type=2, axis=0, norm='ortho')[:Mel_bands]
     
        #Agrega MFCC resultante a lista
        mfccs.append(mfcc)
        
    return np.asarray(mfccs)

# %%
#Caulcula MFCCs de entrenamiento
trainMFCCs = calculoMFCCs(trainAudios)
#Caulcula MFCCs de prueba
testMFCCs = calculoMFCCs(testAudios)
#Caulcula MFCCs de evaluación
evalMFCCs = calculoMFCCs(evalAudios)

# %%
#Dimensiones de MFCCs
print('Las dimenciones de los MFCCs de entrenamiento son:\t', trainMFCCs.shape)
print('Las dimenciones de los MFCCs de prueba son:\t\t', testMFCCs.shape)
print('Las dimenciones de los MFCCs de evaluación son:\t\t', evalMFCCs.shape)

#Valor máximo en el arreglo de MFCCs
print('\nEl valor máximo de los MFCCs son: ', np.amax(trainMFCCs))
#Valor mínimo en el arreglo de MFCCs
print('El valor mínimo de los MFCCs son: ', np.amin(trainMFCCs))
# Out:
# Las dimenciones de los MFCCs de entrenamiento son:	 (12000, 20, 63)
# Las dimenciones de los MFCCs de prueba son:		 (1200, 20, 63)
# Las dimenciones de los MFCCs de evaluación son:		 (800, 20, 63)
#
# El valor máximo de los MFCCs son:  115.39541804597611
# El valor mínimo de los MFCCs son:  -347.989049043822

# %% [markdown]
# ### Muestra Audios

# %%
#Muestra de audio a indicar
num_Audio = 11005
AudioSample = trainAudios[num_Audio]

# %%
#Grafica la seña de audio elegida
plt.figure(figsize=(14, 5))
plt.plot(AudioSample)
plt.title("Señal de audio", {'fontsize':20, 'fontweight':'bold'})
plt.show()

#Reproduce audio
ipd.Audio(AudioSample, rate= sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Muestra MFCC del audio elegido
# Plot the figure
print(trainMFCCs[num_Audio].shape)
plt.figure(figsize=(14, 5))
librosa.display.specshow(trainMFCCs[num_Audio], sr=sampling_rate, hop_length=Size_off, x_axis='time')
plt.colorbar()
# Out:
# (20, 63)

# %%
###COMPARATIVA CON LIBROSA###
#Muestra MFCC del audio elegido
mfcc_lib = librosa.feature.mfcc(y=trainAudios[num_Audio], 
                                sr=sampling_rate, 
                                n_mfcc=Mel_bands, 
                                hop_length=Size_off, 
                                n_fft=Size_win,
                                n_mels = Mel_bands,
                               center=False)

print(mfcc_lib.shape)
# Plot the figure
plt.figure(figsize=(14, 5))
librosa.display.specshow(mfcc_lib, sr=sampling_rate, hop_length=Size_off, x_axis='time')
plt.colorbar()
# Out:
# (20, 63)

# %% [markdown]
# ###  Modelo CNN

# %%
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.optimizers import RMSprop
#Instancia modelo con arquitectura de la red
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', 
                         kernel_regularizer=l2(0.57), padding='same', strides=1,
                         input_shape=(trainMFCCs.shape[1], trainMFCCs.shape[2], 1)),
  tf.keras.layers.MaxPooling2D(3, 3), 
  tf.keras.layers.Conv2D(16, (3,3), padding='same', strides=1, activation='relu'),
  tf.keras.layers.Conv2D(16, (3,3), padding='same', strides=1, activation='relu'),
  tf.keras.layers.MaxPooling2D(3, 3),
    
  tf.keras.layers.Flatten(),
    
  tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=l2(0.57)),
  tf.keras.layers.Dropout(0.36),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dropout(0.36),
  tf.keras.layers.Dense(1, activation='sigmoid')
])


#Compila el modelo
new_learning_rate = 0.00047
optimizer = Adam(learning_rate=new_learning_rate)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

#Imprime un resumen del modelo
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 20, 63, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 21, 32)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 6, 21, 16)         4624
#
#  conv2d_8 (Conv2D)           (None, 6, 21, 16)         2320
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 7, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 224)               0
#
#  dense_6 (Dense)             (None, 32)                7200
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 32)                1056
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 15,553
# Trainable params: 15,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

epochs=250
# Crear ModelCheckpoint callback
model_checkpoint = ModelCheckpoint('best_model_checkpoint/best_model_epoch_{epoch:02d}.h5', monitor='val_loss', save_best_only=True, 
                                   save_weights_only=False, mode='min', verbose=1)
# Luego ejecutas model.fit
history = model.fit(trainMFCCs, trainLabels, validation_data=(testMFCCs, testLabels), 
                    epochs=epochs, batch_size=490, verbose=2, callbacks=[model_checkpoint])
# Out:
# Epoch 1/250
# 2024-04-09 04:38:06.829167: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 60480000 exceeds 10% of free system memory.
# 2024-04-09 04:38:06.894850: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 60480000 exceeds 10% of free system memory.
# 2024-04-09 04:38:08.525988: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2024-04-09 04:38:09.292822: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-04-09 04:38:09.292851: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2024-04-09 04:38:09.292894: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:318] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-04-09 04:38:10.130902: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Epoch 1: val_loss improved from inf to 26.98112, saving model to best_model_checkpoint/best_model_epoch_01.h5
# 25/25 - 4s - loss: 30.6682 - accuracy: 0.5000 - val_loss: 26.9811 - val_accuracy: 0.5275 - 4s/epoch - 160ms/step
# Epoch 2/250
#
# Epoch 2: val_loss improved from 26.98112 to 21.36771, saving model to best_model_checkpoint/best_model_epoch_02.h5
# 25/25 - 0s - loss: 24.2631 - accuracy: 0.5117 - val_loss: 21.3677 - val_accuracy: 0.5975 - 250ms/epoch - 10ms/step
# Epoch 3/250
#
# Epoch 3: val_loss improved from 21.36771 to 16.83996, saving model to best_model_checkpoint/best_model_epoch_03.h5
# 25/25 - 0s - loss: 19.1665 - accuracy: 0.5445 - val_loss: 16.8400 - val_accuracy: 0.6308 - 254ms/epoch - 10ms/step
# Epoch 4/250
#
# Epoch 4: val_loss improved from 16.83996 to 13.22136, saving model to best_model_checkpoint/best_model_epoch_04.h5
# 25/25 - 0s - loss: 15.0839 - accuracy: 0.5612 - val_loss: 13.2214 - val_accuracy: 0.6533 - 248ms/epoch - 10ms/step
# Epoch 5/250
#
# Epoch 5: val_loss improved from 13.22136 to 10.34517, saving model to best_model_checkpoint/best_model_epoch_05.h5
# 25/25 - 0s - loss: 11.8310 - accuracy: 0.5773 - val_loss: 10.3452 - val_accuracy: 0.6658 - 255ms/epoch - 10ms/step
# Epoch 6/250
#
# Epoch 6: val_loss improved from 10.34517 to 8.07726, saving model to best_model_checkpoint/best_model_epoch_06.h5
# 25/25 - 0s - loss: 9.2534 - accuracy: 0.5963 - val_loss: 8.0773 - val_accuracy: 0.6817 - 251ms/epoch - 10ms/step
# Epoch 7/250
#
# Epoch 7: val_loss improved from 8.07726 to 6.29387, saving model to best_model_checkpoint/best_model_epoch_07.h5
# 25/25 - 0s - loss: 7.2214 - accuracy: 0.6118 - val_loss: 6.2939 - val_accuracy: 0.6758 - 251ms/epoch - 10ms/step
# Epoch 8/250
#
# Epoch 8: val_loss improved from 6.29387 to 4.90749, saving model to best_model_checkpoint/best_model_epoch_08.h5
# 25/25 - 0s - loss: 5.6371 - accuracy: 0.6175 - val_loss: 4.9075 - val_accuracy: 0.6800 - 252ms/epoch - 10ms/step
# Epoch 9/250
#
# Epoch 9: val_loss improved from 4.90749 to 3.83291, saving model to best_model_checkpoint/best_model_epoch_09.h5
# 25/25 - 0s - loss: 4.4030 - accuracy: 0.6332 - val_loss: 3.8329 - val_accuracy: 0.6850 - 241ms/epoch - 10ms/step
# Epoch 10/250
#
# Epoch 10: val_loss improved from 3.83291 to 3.00379, saving model to best_model_checkpoint/best_model_epoch_10.h5
# 25/25 - 0s - loss: 3.4481 - accuracy: 0.6485 - val_loss: 3.0038 - val_accuracy: 0.6958 - 251ms/epoch - 10ms/step
# Epoch 11/250
#
# Epoch 11: val_loss improved from 3.00379 to 2.37318, saving model to best_model_checkpoint/best_model_epoch_11.h5
# 25/25 - 0s - loss: 2.7210 - accuracy: 0.6597 - val_loss: 2.3732 - val_accuracy: 0.7042 - 255ms/epoch - 10ms/step
# Epoch 12/250
#
# Epoch 12: val_loss improved from 2.37318 to 1.88747, saving model to best_model_checkpoint/best_model_epoch_12.h5
# 25/25 - 0s - loss: 2.1612 - accuracy: 0.6790 - val_loss: 1.8875 - val_accuracy: 0.7217 - 248ms/epoch - 10ms/step
# Epoch 13/250
#
# Epoch 13: val_loss improved from 1.88747 to 1.52615, saving model to best_model_checkpoint/best_model_epoch_13.h5
# 25/25 - 0s - loss: 1.7405 - accuracy: 0.6933 - val_loss: 1.5262 - val_accuracy: 0.7300 - 253ms/epoch - 10ms/step
# Epoch 14/250
#
# Epoch 14: val_loss improved from 1.52615 to 1.28602, saving model to best_model_checkpoint/best_model_epoch_14.h5
# 25/25 - 0s - loss: 1.4322 - accuracy: 0.6934 - val_loss: 1.2860 - val_accuracy: 0.6942 - 256ms/epoch - 10ms/step
# Epoch 15/250
#
# Epoch 15: val_loss improved from 1.28602 to 1.06662, saving model to best_model_checkpoint/best_model_epoch_15.h5
# 25/25 - 0s - loss: 1.2019 - accuracy: 0.7034 - val_loss: 1.0666 - val_accuracy: 0.7342 - 250ms/epoch - 10ms/step
# Epoch 16/250
#
# Epoch 16: val_loss improved from 1.06662 to 0.93359, saving model to best_model_checkpoint/best_model_epoch_16.h5
# 25/25 - 0s - loss: 1.0284 - accuracy: 0.7072 - val_loss: 0.9336 - val_accuracy: 0.7325 - 249ms/epoch - 10ms/step
# Epoch 17/250
#
# Epoch 17: val_loss improved from 0.93359 to 0.82101, saving model to best_model_checkpoint/best_model_epoch_17.h5
# 25/25 - 0s - loss: 0.8930 - accuracy: 0.7286 - val_loss: 0.8210 - val_accuracy: 0.7392 - 251ms/epoch - 10ms/step
# Epoch 18/250
#
# Epoch 18: val_loss improved from 0.82101 to 0.76495, saving model to best_model_checkpoint/best_model_epoch_18.h5
# 25/25 - 0s - loss: 0.8112 - accuracy: 0.7251 - val_loss: 0.7650 - val_accuracy: 0.7267 - 251ms/epoch - 10ms/step
# Epoch 19/250
#
# Epoch 19: val_loss improved from 0.76495 to 0.68624, saving model to best_model_checkpoint/best_model_epoch_19.h5
# 25/25 - 0s - loss: 0.7285 - accuracy: 0.7408 - val_loss: 0.6862 - val_accuracy: 0.7483 - 255ms/epoch - 10ms/step
# Epoch 20/250
#
# Epoch 20: val_loss improved from 0.68624 to 0.65299, saving model to best_model_checkpoint/best_model_epoch_20.h5
# 25/25 - 0s - loss: 0.6747 - accuracy: 0.7541 - val_loss: 0.6530 - val_accuracy: 0.7500 - 250ms/epoch - 10ms/step
# Epoch 21/250
#
# Epoch 21: val_loss did not improve from 0.65299
# 25/25 - 0s - loss: 0.6536 - accuracy: 0.7471 - val_loss: 0.6686 - val_accuracy: 0.6975 - 227ms/epoch - 9ms/step
# Epoch 22/250
#
# Epoch 22: val_loss improved from 0.65299 to 0.59642, saving model to best_model_checkpoint/best_model_epoch_22.h5
# 25/25 - 0s - loss: 0.6227 - accuracy: 0.7499 - val_loss: 0.5964 - val_accuracy: 0.7558 - 246ms/epoch - 10ms/step
# Epoch 23/250
#
# Epoch 23: val_loss improved from 0.59642 to 0.58456, saving model to best_model_checkpoint/best_model_epoch_23.h5
# 25/25 - 0s - loss: 0.5919 - accuracy: 0.7689 - val_loss: 0.5846 - val_accuracy: 0.7700 - 244ms/epoch - 10ms/step
# Epoch 24/250
#
# Epoch 24: val_loss improved from 0.58456 to 0.57436, saving model to best_model_checkpoint/best_model_epoch_24.h5
# 25/25 - 0s - loss: 0.5749 - accuracy: 0.7741 - val_loss: 0.5744 - val_accuracy: 0.7592 - 252ms/epoch - 10ms/step
# Epoch 25/250
#
# Epoch 25: val_loss did not improve from 0.57436
# 25/25 - 0s - loss: 0.5731 - accuracy: 0.7695 - val_loss: 0.6167 - val_accuracy: 0.7200 - 225ms/epoch - 9ms/step
# Epoch 26/250
#
# Epoch 26: val_loss improved from 0.57436 to 0.55954, saving model to best_model_checkpoint/best_model_epoch_26.h5
# 25/25 - 0s - loss: 0.5751 - accuracy: 0.7604 - val_loss: 0.5595 - val_accuracy: 0.7692 - 245ms/epoch - 10ms/step
# Epoch 27/250
#
# Epoch 27: val_loss improved from 0.55954 to 0.54575, saving model to best_model_checkpoint/best_model_epoch_27.h5
# 25/25 - 0s - loss: 0.5600 - accuracy: 0.7747 - val_loss: 0.5457 - val_accuracy: 0.7792 - 248ms/epoch - 10ms/step
# Epoch 28/250
#
# Epoch 28: val_loss did not improve from 0.54575
# 25/25 - 0s - loss: 0.5358 - accuracy: 0.7849 - val_loss: 0.5516 - val_accuracy: 0.7583 - 230ms/epoch - 9ms/step
# Epoch 29/250
#
# Epoch 29: val_loss did not improve from 0.54575
# 25/25 - 0s - loss: 0.5300 - accuracy: 0.7912 - val_loss: 0.5632 - val_accuracy: 0.7642 - 226ms/epoch - 9ms/step
# Epoch 30/250
#
# Epoch 30: val_loss improved from 0.54575 to 0.53450, saving model to best_model_checkpoint/best_model_epoch_30.h5
# 25/25 - 0s - loss: 0.5190 - accuracy: 0.7960 - val_loss: 0.5345 - val_accuracy: 0.7775 - 254ms/epoch - 10ms/step
# Epoch 31/250
#
# Epoch 31: val_loss did not improve from 0.53450
# 25/25 - 0s - loss: 0.5054 - accuracy: 0.8066 - val_loss: 0.5372 - val_accuracy: 0.7767 - 236ms/epoch - 9ms/step
# Epoch 32/250
#
# Epoch 32: val_loss improved from 0.53450 to 0.51489, saving model to best_model_checkpoint/best_model_epoch_32.h5
# 25/25 - 0s - loss: 0.5283 - accuracy: 0.7868 - val_loss: 0.5149 - val_accuracy: 0.7867 - 253ms/epoch - 10ms/step
# Epoch 33/250
#
# Epoch 33: val_loss did not improve from 0.51489
# 25/25 - 0s - loss: 0.5101 - accuracy: 0.7988 - val_loss: 0.5323 - val_accuracy: 0.7675 - 219ms/epoch - 9ms/step
# Epoch 34/250
#
# Epoch 34: val_loss did not improve from 0.51489
# 25/25 - 0s - loss: 0.5061 - accuracy: 0.8025 - val_loss: 0.5184 - val_accuracy: 0.7833 - 223ms/epoch - 9ms/step
# Epoch 35/250
#
# Epoch 35: val_loss did not improve from 0.51489
# 25/25 - 0s - loss: 0.5065 - accuracy: 0.8004 - val_loss: 0.5397 - val_accuracy: 0.7733 - 228ms/epoch - 9ms/step
# Epoch 36/250
#
# Epoch 36: val_loss did not improve from 0.51489
# 25/25 - 0s - loss: 0.4866 - accuracy: 0.8145 - val_loss: 0.5276 - val_accuracy: 0.7792 - 227ms/epoch - 9ms/step
# Epoch 37/250
#
# Epoch 37: val_loss improved from 0.51489 to 0.50961, saving model to best_model_checkpoint/best_model_epoch_37.h5
# 25/25 - 0s - loss: 0.4805 - accuracy: 0.8171 - val_loss: 0.5096 - val_accuracy: 0.7858 - 247ms/epoch - 10ms/step
# Epoch 38/250
#
# Epoch 38: val_loss improved from 0.50961 to 0.50529, saving model to best_model_checkpoint/best_model_epoch_38.h5
# 25/25 - 0s - loss: 0.4885 - accuracy: 0.8077 - val_loss: 0.5053 - val_accuracy: 0.7883 - 255ms/epoch - 10ms/step
# Epoch 39/250
#
# Epoch 39: val_loss did not improve from 0.50529
# 25/25 - 0s - loss: 0.4775 - accuracy: 0.8201 - val_loss: 0.5138 - val_accuracy: 0.7800 - 226ms/epoch - 9ms/step
# Epoch 40/250
#
# Epoch 40: val_loss did not improve from 0.50529
# 25/25 - 0s - loss: 0.4777 - accuracy: 0.8152 - val_loss: 0.5235 - val_accuracy: 0.7842 - 229ms/epoch - 9ms/step
# Epoch 41/250
#
# Epoch 41: val_loss did not improve from 0.50529
# 25/25 - 0s - loss: 0.4754 - accuracy: 0.8176 - val_loss: 0.5265 - val_accuracy: 0.7767 - 227ms/epoch - 9ms/step
# Epoch 42/250
#
# Epoch 42: val_loss did not improve from 0.50529
# 25/25 - 0s - loss: 0.4737 - accuracy: 0.8207 - val_loss: 0.6062 - val_accuracy: 0.7208 - 215ms/epoch - 9ms/step
# Epoch 43/250
#
# Epoch 43: val_loss improved from 0.50529 to 0.50044, saving model to best_model_checkpoint/best_model_epoch_43.h5
# 25/25 - 0s - loss: 0.4730 - accuracy: 0.8204 - val_loss: 0.5004 - val_accuracy: 0.7883 - 246ms/epoch - 10ms/step
# Epoch 44/250
#
# Epoch 44: val_loss did not improve from 0.50044
# 25/25 - 0s - loss: 0.4671 - accuracy: 0.8179 - val_loss: 0.5174 - val_accuracy: 0.7808 - 228ms/epoch - 9ms/step
# Epoch 45/250
#
# Epoch 45: val_loss did not improve from 0.50044
# 25/25 - 0s - loss: 0.4564 - accuracy: 0.8300 - val_loss: 0.5278 - val_accuracy: 0.7783 - 234ms/epoch - 9ms/step
# Epoch 46/250
#
# Epoch 46: val_loss improved from 0.50044 to 0.49232, saving model to best_model_checkpoint/best_model_epoch_46.h5
# 25/25 - 0s - loss: 0.4539 - accuracy: 0.8290 - val_loss: 0.4923 - val_accuracy: 0.7900 - 245ms/epoch - 10ms/step
# Epoch 47/250
#
# Epoch 47: val_loss did not improve from 0.49232
# 25/25 - 0s - loss: 0.4563 - accuracy: 0.8282 - val_loss: 0.5146 - val_accuracy: 0.7833 - 231ms/epoch - 9ms/step
# Epoch 48/250
#
# Epoch 48: val_loss improved from 0.49232 to 0.48494, saving model to best_model_checkpoint/best_model_epoch_48.h5
# 25/25 - 0s - loss: 0.4435 - accuracy: 0.8366 - val_loss: 0.4849 - val_accuracy: 0.8000 - 247ms/epoch - 10ms/step
# Epoch 49/250
#
# Epoch 49: val_loss did not improve from 0.48494
# 25/25 - 0s - loss: 0.4493 - accuracy: 0.8332 - val_loss: 0.4994 - val_accuracy: 0.7908 - 225ms/epoch - 9ms/step
# Epoch 50/250
#
# Epoch 50: val_loss did not improve from 0.48494
# 25/25 - 0s - loss: 0.4636 - accuracy: 0.8196 - val_loss: 0.4991 - val_accuracy: 0.7883 - 216ms/epoch - 9ms/step
# Epoch 51/250
#
# Epoch 51: val_loss did not improve from 0.48494
# 25/25 - 0s - loss: 0.4370 - accuracy: 0.8385 - val_loss: 0.4910 - val_accuracy: 0.7908 - 221ms/epoch - 9ms/step
# Epoch 52/250
#
# Epoch 52: val_loss improved from 0.48494 to 0.48457, saving model to best_model_checkpoint/best_model_epoch_52.h5
# 25/25 - 0s - loss: 0.4323 - accuracy: 0.8444 - val_loss: 0.4846 - val_accuracy: 0.7908 - 246ms/epoch - 10ms/step
# Epoch 53/250
#
# Epoch 53: val_loss improved from 0.48457 to 0.47666, saving model to best_model_checkpoint/best_model_epoch_53.h5
# 25/25 - 0s - loss: 0.4400 - accuracy: 0.8357 - val_loss: 0.4767 - val_accuracy: 0.8033 - 252ms/epoch - 10ms/step
# Epoch 54/250
#
# Epoch 54: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4305 - accuracy: 0.8397 - val_loss: 0.5368 - val_accuracy: 0.7700 - 229ms/epoch - 9ms/step
# Epoch 55/250
#
# Epoch 55: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4376 - accuracy: 0.8363 - val_loss: 0.5133 - val_accuracy: 0.7833 - 227ms/epoch - 9ms/step
# Epoch 56/250
#
# Epoch 56: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4280 - accuracy: 0.8443 - val_loss: 0.4861 - val_accuracy: 0.7958 - 228ms/epoch - 9ms/step
# Epoch 57/250
#
# Epoch 57: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4423 - accuracy: 0.8350 - val_loss: 0.5028 - val_accuracy: 0.7842 - 231ms/epoch - 9ms/step
# Epoch 58/250
#
# Epoch 58: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4223 - accuracy: 0.8474 - val_loss: 0.5349 - val_accuracy: 0.7742 - 230ms/epoch - 9ms/step
# Epoch 59/250
#
# Epoch 59: val_loss did not improve from 0.47666
# 25/25 - 0s - loss: 0.4249 - accuracy: 0.8442 - val_loss: 0.5400 - val_accuracy: 0.7600 - 228ms/epoch - 9ms/step
# Epoch 60/250
#
# Epoch 60: val_loss improved from 0.47666 to 0.47488, saving model to best_model_checkpoint/best_model_epoch_60.h5
# 25/25 - 0s - loss: 0.4190 - accuracy: 0.8445 - val_loss: 0.4749 - val_accuracy: 0.7950 - 252ms/epoch - 10ms/step
# Epoch 61/250
#
# Epoch 61: val_loss did not improve from 0.47488
# 25/25 - 0s - loss: 0.4121 - accuracy: 0.8527 - val_loss: 0.5433 - val_accuracy: 0.7658 - 232ms/epoch - 9ms/step
# Epoch 62/250
#
# Epoch 62: val_loss did not improve from 0.47488
# 25/25 - 0s - loss: 0.4160 - accuracy: 0.8486 - val_loss: 0.5352 - val_accuracy: 0.7650 - 228ms/epoch - 9ms/step
# Epoch 63/250
#
# Epoch 63: val_loss did not improve from 0.47488
# 25/25 - 0s - loss: 0.4083 - accuracy: 0.8533 - val_loss: 0.4875 - val_accuracy: 0.7975 - 229ms/epoch - 9ms/step
# Epoch 64/250
#
# Epoch 64: val_loss improved from 0.47488 to 0.45845, saving model to best_model_checkpoint/best_model_epoch_64.h5
# 25/25 - 0s - loss: 0.4150 - accuracy: 0.8491 - val_loss: 0.4585 - val_accuracy: 0.8058 - 245ms/epoch - 10ms/step
# Epoch 65/250
#
# Epoch 65: val_loss did not improve from 0.45845
# 25/25 - 0s - loss: 0.4193 - accuracy: 0.8487 - val_loss: 0.5680 - val_accuracy: 0.7575 - 231ms/epoch - 9ms/step
# Epoch 66/250
#
# Epoch 66: val_loss improved from 0.45845 to 0.45600, saving model to best_model_checkpoint/best_model_epoch_66.h5
# 25/25 - 0s - loss: 0.4281 - accuracy: 0.8405 - val_loss: 0.4560 - val_accuracy: 0.8067 - 248ms/epoch - 10ms/step
# Epoch 67/250
#
# Epoch 67: val_loss improved from 0.45600 to 0.45014, saving model to best_model_checkpoint/best_model_epoch_67.h5
# 25/25 - 0s - loss: 0.4009 - accuracy: 0.8568 - val_loss: 0.4501 - val_accuracy: 0.8158 - 237ms/epoch - 9ms/step
# Epoch 68/250
#
# Epoch 68: val_loss did not improve from 0.45014
# 25/25 - 0s - loss: 0.4178 - accuracy: 0.8463 - val_loss: 0.5529 - val_accuracy: 0.7617 - 226ms/epoch - 9ms/step
# Epoch 69/250
#
# Epoch 69: val_loss improved from 0.45014 to 0.44544, saving model to best_model_checkpoint/best_model_epoch_69.h5
# 25/25 - 0s - loss: 0.4043 - accuracy: 0.8531 - val_loss: 0.4454 - val_accuracy: 0.8092 - 248ms/epoch - 10ms/step
# Epoch 70/250
#
# Epoch 70: val_loss did not improve from 0.44544
# 25/25 - 0s - loss: 0.4332 - accuracy: 0.8366 - val_loss: 0.4533 - val_accuracy: 0.8100 - 231ms/epoch - 9ms/step
# Epoch 71/250
#
# Epoch 71: val_loss did not improve from 0.44544
# 25/25 - 0s - loss: 0.3966 - accuracy: 0.8595 - val_loss: 0.4705 - val_accuracy: 0.8000 - 230ms/epoch - 9ms/step
# Epoch 72/250
#
# Epoch 72: val_loss did not improve from 0.44544
# 25/25 - 0s - loss: 0.4111 - accuracy: 0.8492 - val_loss: 0.4665 - val_accuracy: 0.8092 - 230ms/epoch - 9ms/step
# Epoch 73/250
#
# Epoch 73: val_loss did not improve from 0.44544
# 25/25 - 0s - loss: 0.3932 - accuracy: 0.8608 - val_loss: 0.4513 - val_accuracy: 0.8117 - 227ms/epoch - 9ms/step
# Epoch 74/250
#
# Epoch 74: val_loss did not improve from 0.44544
# 25/25 - 0s - loss: 0.3853 - accuracy: 0.8657 - val_loss: 0.4475 - val_accuracy: 0.8192 - 228ms/epoch - 9ms/step
# Epoch 75/250
#
# Epoch 75: val_loss improved from 0.44544 to 0.43686, saving model to best_model_checkpoint/best_model_epoch_75.h5
# 25/25 - 0s - loss: 0.3952 - accuracy: 0.8606 - val_loss: 0.4369 - val_accuracy: 0.8200 - 244ms/epoch - 10ms/step
# Epoch 76/250
#
# Epoch 76: val_loss improved from 0.43686 to 0.43662, saving model to best_model_checkpoint/best_model_epoch_76.h5
# 25/25 - 0s - loss: 0.3788 - accuracy: 0.8687 - val_loss: 0.4366 - val_accuracy: 0.8175 - 237ms/epoch - 9ms/step
# Epoch 77/250
#
# Epoch 77: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3925 - accuracy: 0.8625 - val_loss: 0.4685 - val_accuracy: 0.8100 - 229ms/epoch - 9ms/step
# Epoch 78/250
#
# Epoch 78: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3943 - accuracy: 0.8587 - val_loss: 0.4479 - val_accuracy: 0.8192 - 231ms/epoch - 9ms/step
# Epoch 79/250
#
# Epoch 79: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3838 - accuracy: 0.8668 - val_loss: 0.4620 - val_accuracy: 0.8150 - 228ms/epoch - 9ms/step
# Epoch 80/250
#
# Epoch 80: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3784 - accuracy: 0.8674 - val_loss: 0.4453 - val_accuracy: 0.8167 - 233ms/epoch - 9ms/step
# Epoch 81/250
#
# Epoch 81: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3685 - accuracy: 0.8726 - val_loss: 0.4619 - val_accuracy: 0.8042 - 229ms/epoch - 9ms/step
# Epoch 82/250
#
# Epoch 82: val_loss did not improve from 0.43662
# 25/25 - 0s - loss: 0.3700 - accuracy: 0.8716 - val_loss: 0.4686 - val_accuracy: 0.8142 - 230ms/epoch - 9ms/step
# Epoch 83/250
#
# Epoch 83: val_loss improved from 0.43662 to 0.42699, saving model to best_model_checkpoint/best_model_epoch_83.h5
# 25/25 - 0s - loss: 0.3680 - accuracy: 0.8727 - val_loss: 0.4270 - val_accuracy: 0.8242 - 254ms/epoch - 10ms/step
# Epoch 84/250
#
# Epoch 84: val_loss did not improve from 0.42699
# 25/25 - 0s - loss: 0.3674 - accuracy: 0.8752 - val_loss: 0.5234 - val_accuracy: 0.7842 - 215ms/epoch - 9ms/step
# Epoch 85/250
#
# Epoch 85: val_loss did not improve from 0.42699
# 25/25 - 0s - loss: 0.3796 - accuracy: 0.8683 - val_loss: 0.4549 - val_accuracy: 0.8200 - 226ms/epoch - 9ms/step
# Epoch 86/250
#
# Epoch 86: val_loss did not improve from 0.42699
# 25/25 - 0s - loss: 0.3865 - accuracy: 0.8637 - val_loss: 0.4515 - val_accuracy: 0.8183 - 226ms/epoch - 9ms/step
# Epoch 87/250
#
# Epoch 87: val_loss did not improve from 0.42699
# 25/25 - 0s - loss: 0.3805 - accuracy: 0.8658 - val_loss: 0.4847 - val_accuracy: 0.8033 - 233ms/epoch - 9ms/step
# Epoch 88/250
#
# Epoch 88: val_loss did not improve from 0.42699
# 25/25 - 0s - loss: 0.3639 - accuracy: 0.8776 - val_loss: 0.4465 - val_accuracy: 0.8258 - 236ms/epoch - 9ms/step
# Epoch 89/250
#
# Epoch 89: val_loss improved from 0.42699 to 0.42050, saving model to best_model_checkpoint/best_model_epoch_89.h5
# 25/25 - 0s - loss: 0.3621 - accuracy: 0.8779 - val_loss: 0.4205 - val_accuracy: 0.8317 - 261ms/epoch - 10ms/step
# Epoch 90/250
#
# Epoch 90: val_loss did not improve from 0.42050
# 25/25 - 0s - loss: 0.3646 - accuracy: 0.8745 - val_loss: 0.4644 - val_accuracy: 0.8192 - 236ms/epoch - 9ms/step
# Epoch 91/250
#
# Epoch 91: val_loss did not improve from 0.42050
# 25/25 - 0s - loss: 0.3528 - accuracy: 0.8832 - val_loss: 0.4259 - val_accuracy: 0.8258 - 241ms/epoch - 10ms/step
# Epoch 92/250
#
# Epoch 92: val_loss did not improve from 0.42050
# 25/25 - 0s - loss: 0.3612 - accuracy: 0.8767 - val_loss: 0.4334 - val_accuracy: 0.8250 - 219ms/epoch - 9ms/step
# Epoch 93/250
#
# Epoch 93: val_loss improved from 0.42050 to 0.41664, saving model to best_model_checkpoint/best_model_epoch_93.h5
# 25/25 - 0s - loss: 0.3617 - accuracy: 0.8758 - val_loss: 0.4166 - val_accuracy: 0.8350 - 240ms/epoch - 10ms/step
# Epoch 94/250
#
# Epoch 94: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3551 - accuracy: 0.8827 - val_loss: 0.4625 - val_accuracy: 0.8175 - 219ms/epoch - 9ms/step
# Epoch 95/250
#
# Epoch 95: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3489 - accuracy: 0.8830 - val_loss: 0.4555 - val_accuracy: 0.8217 - 220ms/epoch - 9ms/step
# Epoch 96/250
#
# Epoch 96: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3575 - accuracy: 0.8768 - val_loss: 0.4802 - val_accuracy: 0.8025 - 218ms/epoch - 9ms/step
# Epoch 97/250
#
# Epoch 97: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3474 - accuracy: 0.8856 - val_loss: 0.4253 - val_accuracy: 0.8258 - 219ms/epoch - 9ms/step
# Epoch 98/250
#
# Epoch 98: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3670 - accuracy: 0.8709 - val_loss: 0.4440 - val_accuracy: 0.8225 - 219ms/epoch - 9ms/step
# Epoch 99/250
#
# Epoch 99: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3453 - accuracy: 0.8848 - val_loss: 0.4274 - val_accuracy: 0.8258 - 219ms/epoch - 9ms/step
# Epoch 100/250
#
# Epoch 100: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3512 - accuracy: 0.8803 - val_loss: 0.4243 - val_accuracy: 0.8300 - 231ms/epoch - 9ms/step
# Epoch 101/250
#
# Epoch 101: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3663 - accuracy: 0.8731 - val_loss: 0.4235 - val_accuracy: 0.8275 - 211ms/epoch - 8ms/step
# Epoch 102/250
#
# Epoch 102: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3586 - accuracy: 0.8767 - val_loss: 0.4320 - val_accuracy: 0.8408 - 204ms/epoch - 8ms/step
# Epoch 103/250
#
# Epoch 103: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3564 - accuracy: 0.8752 - val_loss: 0.4258 - val_accuracy: 0.8333 - 211ms/epoch - 8ms/step
# Epoch 104/250
#
# Epoch 104: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3413 - accuracy: 0.8845 - val_loss: 0.4219 - val_accuracy: 0.8342 - 217ms/epoch - 9ms/step
# Epoch 105/250
#
# Epoch 105: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3377 - accuracy: 0.8878 - val_loss: 0.4215 - val_accuracy: 0.8283 - 216ms/epoch - 9ms/step
# Epoch 106/250
#
# Epoch 106: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3414 - accuracy: 0.8842 - val_loss: 0.4245 - val_accuracy: 0.8367 - 219ms/epoch - 9ms/step
# Epoch 107/250
#
# Epoch 107: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3403 - accuracy: 0.8869 - val_loss: 0.4280 - val_accuracy: 0.8275 - 215ms/epoch - 9ms/step
# Epoch 108/250
#
# Epoch 108: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3337 - accuracy: 0.8901 - val_loss: 0.4182 - val_accuracy: 0.8342 - 209ms/epoch - 8ms/step
# Epoch 109/250
#
# Epoch 109: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3313 - accuracy: 0.8901 - val_loss: 0.4241 - val_accuracy: 0.8375 - 212ms/epoch - 8ms/step
# Epoch 110/250
#
# Epoch 110: val_loss did not improve from 0.41664
# 25/25 - 0s - loss: 0.3348 - accuracy: 0.8884 - val_loss: 0.4220 - val_accuracy: 0.8342 - 211ms/epoch - 8ms/step
# Epoch 111/250
#
# Epoch 111: val_loss improved from 0.41664 to 0.40919, saving model to best_model_checkpoint/best_model_epoch_111.h5
# 25/25 - 0s - loss: 0.3333 - accuracy: 0.8893 - val_loss: 0.4092 - val_accuracy: 0.8442 - 228ms/epoch - 9ms/step
# Epoch 112/250
#
# Epoch 112: val_loss did not improve from 0.40919
# 25/25 - 0s - loss: 0.3360 - accuracy: 0.8913 - val_loss: 0.4271 - val_accuracy: 0.8350 - 213ms/epoch - 9ms/step
# Epoch 113/250
#
# Epoch 113: val_loss did not improve from 0.40919
# 25/25 - 0s - loss: 0.3275 - accuracy: 0.8929 - val_loss: 0.5251 - val_accuracy: 0.7833 - 222ms/epoch - 9ms/step
# Epoch 114/250
#
# Epoch 114: val_loss did not improve from 0.40919
# 25/25 - 0s - loss: 0.3406 - accuracy: 0.8828 - val_loss: 0.4252 - val_accuracy: 0.8267 - 213ms/epoch - 9ms/step
# Epoch 115/250
#
# Epoch 115: val_loss improved from 0.40919 to 0.40798, saving model to best_model_checkpoint/best_model_epoch_115.h5
# 25/25 - 0s - loss: 0.3311 - accuracy: 0.8917 - val_loss: 0.4080 - val_accuracy: 0.8350 - 231ms/epoch - 9ms/step
# Epoch 116/250
#
# Epoch 116: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3344 - accuracy: 0.8870 - val_loss: 0.4340 - val_accuracy: 0.8267 - 216ms/epoch - 9ms/step
# Epoch 117/250
#
# Epoch 117: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3154 - accuracy: 0.8976 - val_loss: 0.4139 - val_accuracy: 0.8375 - 212ms/epoch - 8ms/step
# Epoch 118/250
#
# Epoch 118: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3364 - accuracy: 0.8894 - val_loss: 0.5183 - val_accuracy: 0.7967 - 226ms/epoch - 9ms/step
# Epoch 119/250
#
# Epoch 119: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3183 - accuracy: 0.8965 - val_loss: 0.4696 - val_accuracy: 0.8150 - 211ms/epoch - 8ms/step
# Epoch 120/250
#
# Epoch 120: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3226 - accuracy: 0.8927 - val_loss: 0.4119 - val_accuracy: 0.8350 - 204ms/epoch - 8ms/step
# Epoch 121/250
#
# Epoch 121: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3137 - accuracy: 0.8979 - val_loss: 0.4156 - val_accuracy: 0.8333 - 211ms/epoch - 8ms/step
# Epoch 122/250
#
# Epoch 122: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3172 - accuracy: 0.8963 - val_loss: 0.4360 - val_accuracy: 0.8300 - 212ms/epoch - 8ms/step
# Epoch 123/250
#
# Epoch 123: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3202 - accuracy: 0.8933 - val_loss: 0.4491 - val_accuracy: 0.8242 - 212ms/epoch - 8ms/step
# Epoch 124/250
#
# Epoch 124: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3270 - accuracy: 0.8894 - val_loss: 0.4175 - val_accuracy: 0.8367 - 211ms/epoch - 8ms/step
# Epoch 125/250
#
# Epoch 125: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3208 - accuracy: 0.8968 - val_loss: 0.4946 - val_accuracy: 0.8092 - 216ms/epoch - 9ms/step
# Epoch 126/250
#
# Epoch 126: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3158 - accuracy: 0.8962 - val_loss: 0.4392 - val_accuracy: 0.8258 - 211ms/epoch - 8ms/step
# Epoch 127/250
#
# Epoch 127: val_loss did not improve from 0.40798
# 25/25 - 0s - loss: 0.3129 - accuracy: 0.8990 - val_loss: 0.4313 - val_accuracy: 0.8300 - 215ms/epoch - 9ms/step
# Epoch 128/250
#
# Epoch 128: val_loss improved from 0.40798 to 0.39744, saving model to best_model_checkpoint/best_model_epoch_128.h5
# 25/25 - 0s - loss: 0.3182 - accuracy: 0.8948 - val_loss: 0.3974 - val_accuracy: 0.8425 - 230ms/epoch - 9ms/step
# Epoch 129/250
#
# Epoch 129: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3060 - accuracy: 0.9022 - val_loss: 0.4276 - val_accuracy: 0.8283 - 202ms/epoch - 8ms/step
# Epoch 130/250
#
# Epoch 130: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3214 - accuracy: 0.8903 - val_loss: 0.4685 - val_accuracy: 0.8225 - 212ms/epoch - 8ms/step
# Epoch 131/250
#
# Epoch 131: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3043 - accuracy: 0.9059 - val_loss: 0.4236 - val_accuracy: 0.8400 - 215ms/epoch - 9ms/step
# Epoch 132/250
#
# Epoch 132: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3070 - accuracy: 0.9020 - val_loss: 0.4767 - val_accuracy: 0.8092 - 209ms/epoch - 8ms/step
# Epoch 133/250
#
# Epoch 133: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3171 - accuracy: 0.8939 - val_loss: 0.4905 - val_accuracy: 0.8083 - 215ms/epoch - 9ms/step
# Epoch 134/250
#
# Epoch 134: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3013 - accuracy: 0.9034 - val_loss: 0.4843 - val_accuracy: 0.8125 - 223ms/epoch - 9ms/step
# Epoch 135/250
#
# Epoch 135: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3137 - accuracy: 0.8981 - val_loss: 0.4382 - val_accuracy: 0.8358 - 217ms/epoch - 9ms/step
# Epoch 136/250
#
# Epoch 136: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3003 - accuracy: 0.9041 - val_loss: 0.4362 - val_accuracy: 0.8358 - 216ms/epoch - 9ms/step
# Epoch 137/250
#
# Epoch 137: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3136 - accuracy: 0.8995 - val_loss: 0.5602 - val_accuracy: 0.7825 - 218ms/epoch - 9ms/step
# Epoch 138/250
#
# Epoch 138: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3160 - accuracy: 0.8974 - val_loss: 0.5080 - val_accuracy: 0.8075 - 212ms/epoch - 8ms/step
# Epoch 139/250
#
# Epoch 139: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3107 - accuracy: 0.8984 - val_loss: 0.4681 - val_accuracy: 0.8117 - 208ms/epoch - 8ms/step
# Epoch 140/250
#
# Epoch 140: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3188 - accuracy: 0.8943 - val_loss: 0.4124 - val_accuracy: 0.8392 - 212ms/epoch - 8ms/step
# Epoch 141/250
#
# Epoch 141: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3279 - accuracy: 0.8873 - val_loss: 0.4994 - val_accuracy: 0.8042 - 212ms/epoch - 8ms/step
# Epoch 142/250
#
# Epoch 142: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2945 - accuracy: 0.9075 - val_loss: 0.4157 - val_accuracy: 0.8383 - 212ms/epoch - 8ms/step
# Epoch 143/250
#
# Epoch 143: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2933 - accuracy: 0.9087 - val_loss: 0.4229 - val_accuracy: 0.8433 - 214ms/epoch - 9ms/step
# Epoch 144/250
#
# Epoch 144: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2952 - accuracy: 0.9068 - val_loss: 0.4248 - val_accuracy: 0.8325 - 214ms/epoch - 9ms/step
# Epoch 145/250
#
# Epoch 145: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3002 - accuracy: 0.9050 - val_loss: 0.4304 - val_accuracy: 0.8350 - 213ms/epoch - 9ms/step
# Epoch 146/250
#
# Epoch 146: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2908 - accuracy: 0.9091 - val_loss: 0.4492 - val_accuracy: 0.8242 - 223ms/epoch - 9ms/step
# Epoch 147/250
#
# Epoch 147: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3185 - accuracy: 0.8945 - val_loss: 0.4124 - val_accuracy: 0.8392 - 211ms/epoch - 8ms/step
# Epoch 148/250
#
# Epoch 148: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3002 - accuracy: 0.9042 - val_loss: 0.4369 - val_accuracy: 0.8300 - 214ms/epoch - 9ms/step
# Epoch 149/250
#
# Epoch 149: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2934 - accuracy: 0.9078 - val_loss: 0.4209 - val_accuracy: 0.8483 - 226ms/epoch - 9ms/step
# Epoch 150/250
#
# Epoch 150: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2926 - accuracy: 0.9086 - val_loss: 0.4191 - val_accuracy: 0.8367 - 217ms/epoch - 9ms/step
# Epoch 151/250
#
# Epoch 151: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2968 - accuracy: 0.9037 - val_loss: 0.4191 - val_accuracy: 0.8367 - 214ms/epoch - 9ms/step
# Epoch 152/250
#
# Epoch 152: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3030 - accuracy: 0.9006 - val_loss: 0.5295 - val_accuracy: 0.8067 - 215ms/epoch - 9ms/step
# Epoch 153/250
#
# Epoch 153: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2983 - accuracy: 0.9041 - val_loss: 0.4069 - val_accuracy: 0.8425 - 214ms/epoch - 9ms/step
# Epoch 154/250
#
# Epoch 154: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3038 - accuracy: 0.8996 - val_loss: 0.4162 - val_accuracy: 0.8400 - 215ms/epoch - 9ms/step
# Epoch 155/250
#
# Epoch 155: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3155 - accuracy: 0.8947 - val_loss: 0.4145 - val_accuracy: 0.8433 - 214ms/epoch - 9ms/step
# Epoch 156/250
#
# Epoch 156: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2872 - accuracy: 0.9111 - val_loss: 0.4215 - val_accuracy: 0.8425 - 214ms/epoch - 9ms/step
# Epoch 157/250
#
# Epoch 157: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2799 - accuracy: 0.9122 - val_loss: 0.4569 - val_accuracy: 0.8258 - 207ms/epoch - 8ms/step
# Epoch 158/250
#
# Epoch 158: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2811 - accuracy: 0.9143 - val_loss: 0.4617 - val_accuracy: 0.8233 - 211ms/epoch - 8ms/step
# Epoch 159/250
#
# Epoch 159: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2953 - accuracy: 0.9046 - val_loss: 0.4895 - val_accuracy: 0.8183 - 216ms/epoch - 9ms/step
# Epoch 160/250
#
# Epoch 160: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2898 - accuracy: 0.9090 - val_loss: 0.4651 - val_accuracy: 0.8233 - 214ms/epoch - 9ms/step
# Epoch 161/250
#
# Epoch 161: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2998 - accuracy: 0.9032 - val_loss: 0.4115 - val_accuracy: 0.8442 - 214ms/epoch - 9ms/step
# Epoch 162/250
#
# Epoch 162: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2808 - accuracy: 0.9124 - val_loss: 0.5144 - val_accuracy: 0.8092 - 214ms/epoch - 9ms/step
# Epoch 163/250
#
# Epoch 163: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2813 - accuracy: 0.9158 - val_loss: 0.4193 - val_accuracy: 0.8367 - 212ms/epoch - 8ms/step
# Epoch 164/250
#
# Epoch 164: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2892 - accuracy: 0.9075 - val_loss: 0.4212 - val_accuracy: 0.8342 - 217ms/epoch - 9ms/step
# Epoch 165/250
#
# Epoch 165: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2911 - accuracy: 0.9078 - val_loss: 0.4629 - val_accuracy: 0.8233 - 213ms/epoch - 9ms/step
# Epoch 166/250
#
# Epoch 166: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2825 - accuracy: 0.9120 - val_loss: 0.4195 - val_accuracy: 0.8400 - 219ms/epoch - 9ms/step
# Epoch 167/250
#
# Epoch 167: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2720 - accuracy: 0.9178 - val_loss: 0.4356 - val_accuracy: 0.8342 - 211ms/epoch - 8ms/step
# Epoch 168/250
#
# Epoch 168: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2698 - accuracy: 0.9171 - val_loss: 0.4328 - val_accuracy: 0.8317 - 213ms/epoch - 9ms/step
# Epoch 169/250
#
# Epoch 169: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2798 - accuracy: 0.9133 - val_loss: 0.4274 - val_accuracy: 0.8450 - 212ms/epoch - 8ms/step
# Epoch 170/250
#
# Epoch 170: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2665 - accuracy: 0.9169 - val_loss: 0.4401 - val_accuracy: 0.8425 - 214ms/epoch - 9ms/step
# Epoch 171/250
#
# Epoch 171: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2815 - accuracy: 0.9112 - val_loss: 0.5590 - val_accuracy: 0.7942 - 215ms/epoch - 9ms/step
# Epoch 172/250
#
# Epoch 172: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2935 - accuracy: 0.9064 - val_loss: 0.4269 - val_accuracy: 0.8367 - 215ms/epoch - 9ms/step
# Epoch 173/250
#
# Epoch 173: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2761 - accuracy: 0.9154 - val_loss: 0.4245 - val_accuracy: 0.8400 - 216ms/epoch - 9ms/step
# Epoch 174/250
#
# Epoch 174: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2631 - accuracy: 0.9216 - val_loss: 0.4742 - val_accuracy: 0.8242 - 213ms/epoch - 9ms/step
# Epoch 175/250
#
# Epoch 175: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2669 - accuracy: 0.9226 - val_loss: 0.4276 - val_accuracy: 0.8367 - 205ms/epoch - 8ms/step
# Epoch 176/250
#
# Epoch 176: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2651 - accuracy: 0.9195 - val_loss: 0.4237 - val_accuracy: 0.8408 - 204ms/epoch - 8ms/step
# Epoch 177/250
#
# Epoch 177: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2741 - accuracy: 0.9154 - val_loss: 0.4348 - val_accuracy: 0.8450 - 215ms/epoch - 9ms/step
# Epoch 178/250
#
# Epoch 178: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2706 - accuracy: 0.9186 - val_loss: 0.4515 - val_accuracy: 0.8233 - 214ms/epoch - 9ms/step
# Epoch 179/250
#
# Epoch 179: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2695 - accuracy: 0.9178 - val_loss: 0.4368 - val_accuracy: 0.8350 - 214ms/epoch - 9ms/step
# Epoch 180/250
#
# Epoch 180: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2856 - accuracy: 0.9073 - val_loss: 0.4291 - val_accuracy: 0.8358 - 212ms/epoch - 8ms/step
# Epoch 181/250
#
# Epoch 181: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2889 - accuracy: 0.9087 - val_loss: 0.4285 - val_accuracy: 0.8467 - 218ms/epoch - 9ms/step
# Epoch 182/250
#
# Epoch 182: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2892 - accuracy: 0.9059 - val_loss: 0.4860 - val_accuracy: 0.8150 - 219ms/epoch - 9ms/step
# Epoch 183/250
#
# Epoch 183: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3100 - accuracy: 0.8963 - val_loss: 0.4392 - val_accuracy: 0.8383 - 217ms/epoch - 9ms/step
# Epoch 184/250
#
# Epoch 184: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.3045 - accuracy: 0.9040 - val_loss: 0.4252 - val_accuracy: 0.8375 - 217ms/epoch - 9ms/step
# Epoch 185/250
#
# Epoch 185: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2706 - accuracy: 0.9186 - val_loss: 0.4548 - val_accuracy: 0.8258 - 211ms/epoch - 8ms/step
# Epoch 186/250
#
# Epoch 186: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2514 - accuracy: 0.9262 - val_loss: 0.4388 - val_accuracy: 0.8392 - 219ms/epoch - 9ms/step
# Epoch 187/250
#
# Epoch 187: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2773 - accuracy: 0.9133 - val_loss: 0.4528 - val_accuracy: 0.8367 - 216ms/epoch - 9ms/step
# Epoch 188/250
#
# Epoch 188: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2670 - accuracy: 0.9204 - val_loss: 0.4133 - val_accuracy: 0.8417 - 216ms/epoch - 9ms/step
# Epoch 189/250
#
# Epoch 189: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2806 - accuracy: 0.9136 - val_loss: 0.5145 - val_accuracy: 0.8058 - 218ms/epoch - 9ms/step
# Epoch 190/250
#
# Epoch 190: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2698 - accuracy: 0.9166 - val_loss: 0.5305 - val_accuracy: 0.8083 - 224ms/epoch - 9ms/step
# Epoch 191/250
#
# Epoch 191: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2839 - accuracy: 0.9074 - val_loss: 0.5909 - val_accuracy: 0.7917 - 219ms/epoch - 9ms/step
# Epoch 192/250
#
# Epoch 192: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2571 - accuracy: 0.9222 - val_loss: 0.4798 - val_accuracy: 0.8300 - 234ms/epoch - 9ms/step
# Epoch 193/250
#
# Epoch 193: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2572 - accuracy: 0.9244 - val_loss: 0.4354 - val_accuracy: 0.8500 - 215ms/epoch - 9ms/step
# Epoch 194/250
#
# Epoch 194: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2513 - accuracy: 0.9271 - val_loss: 0.4377 - val_accuracy: 0.8383 - 210ms/epoch - 8ms/step
# Epoch 195/250
#
# Epoch 195: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2577 - accuracy: 0.9231 - val_loss: 0.4713 - val_accuracy: 0.8200 - 231ms/epoch - 9ms/step
# Epoch 196/250
#
# Epoch 196: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2822 - accuracy: 0.9076 - val_loss: 0.4372 - val_accuracy: 0.8458 - 226ms/epoch - 9ms/step
# Epoch 197/250
#
# Epoch 197: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2713 - accuracy: 0.9178 - val_loss: 0.4669 - val_accuracy: 0.8300 - 218ms/epoch - 9ms/step
# Epoch 198/250
#
# Epoch 198: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2747 - accuracy: 0.9149 - val_loss: 0.4688 - val_accuracy: 0.8242 - 230ms/epoch - 9ms/step
# Epoch 199/250
#
# Epoch 199: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2473 - accuracy: 0.9273 - val_loss: 0.4590 - val_accuracy: 0.8292 - 220ms/epoch - 9ms/step
# Epoch 200/250
#
# Epoch 200: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2493 - accuracy: 0.9275 - val_loss: 0.4733 - val_accuracy: 0.8317 - 218ms/epoch - 9ms/step
# Epoch 201/250
#
# Epoch 201: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2582 - accuracy: 0.9227 - val_loss: 0.4520 - val_accuracy: 0.8308 - 217ms/epoch - 9ms/step
# Epoch 202/250
#
# Epoch 202: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2601 - accuracy: 0.9202 - val_loss: 0.4536 - val_accuracy: 0.8375 - 213ms/epoch - 9ms/step
# Epoch 203/250
#
# Epoch 203: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2494 - accuracy: 0.9251 - val_loss: 0.4778 - val_accuracy: 0.8233 - 208ms/epoch - 8ms/step
# Epoch 204/250
#
# Epoch 204: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2686 - accuracy: 0.9143 - val_loss: 0.4069 - val_accuracy: 0.8417 - 219ms/epoch - 9ms/step
# Epoch 205/250
#
# Epoch 205: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2836 - accuracy: 0.9076 - val_loss: 0.4225 - val_accuracy: 0.8433 - 217ms/epoch - 9ms/step
# Epoch 206/250
#
# Epoch 206: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2517 - accuracy: 0.9273 - val_loss: 0.5012 - val_accuracy: 0.8183 - 235ms/epoch - 9ms/step
# Epoch 207/250
#
# Epoch 207: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2536 - accuracy: 0.9237 - val_loss: 0.4882 - val_accuracy: 0.8250 - 220ms/epoch - 9ms/step
# Epoch 208/250
#
# Epoch 208: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2482 - accuracy: 0.9282 - val_loss: 0.4437 - val_accuracy: 0.8350 - 217ms/epoch - 9ms/step
# Epoch 209/250
#
# Epoch 209: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2446 - accuracy: 0.9292 - val_loss: 0.4726 - val_accuracy: 0.8300 - 222ms/epoch - 9ms/step
# Epoch 210/250
#
# Epoch 210: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2474 - accuracy: 0.9273 - val_loss: 0.4221 - val_accuracy: 0.8425 - 229ms/epoch - 9ms/step
# Epoch 211/250
#
# Epoch 211: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2638 - accuracy: 0.9198 - val_loss: 0.4172 - val_accuracy: 0.8392 - 223ms/epoch - 9ms/step
# Epoch 212/250
#
# Epoch 212: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2499 - accuracy: 0.9261 - val_loss: 0.4867 - val_accuracy: 0.8183 - 210ms/epoch - 8ms/step
# Epoch 213/250
#
# Epoch 213: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2440 - accuracy: 0.9300 - val_loss: 0.4516 - val_accuracy: 0.8442 - 219ms/epoch - 9ms/step
# Epoch 214/250
#
# Epoch 214: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2645 - accuracy: 0.9172 - val_loss: 0.4238 - val_accuracy: 0.8433 - 218ms/epoch - 9ms/step
# Epoch 215/250
#
# Epoch 215: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2365 - accuracy: 0.9333 - val_loss: 0.4321 - val_accuracy: 0.8408 - 219ms/epoch - 9ms/step
# Epoch 216/250
#
# Epoch 216: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2418 - accuracy: 0.9312 - val_loss: 0.6230 - val_accuracy: 0.7842 - 214ms/epoch - 9ms/step
# Epoch 217/250
#
# Epoch 217: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2438 - accuracy: 0.9315 - val_loss: 0.5262 - val_accuracy: 0.8258 - 219ms/epoch - 9ms/step
# Epoch 218/250
#
# Epoch 218: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2366 - accuracy: 0.9320 - val_loss: 0.4687 - val_accuracy: 0.8333 - 219ms/epoch - 9ms/step
# Epoch 219/250
#
# Epoch 219: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2490 - accuracy: 0.9258 - val_loss: 0.5109 - val_accuracy: 0.8275 - 221ms/epoch - 9ms/step
# Epoch 220/250
#
# Epoch 220: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2444 - accuracy: 0.9292 - val_loss: 0.4662 - val_accuracy: 0.8400 - 229ms/epoch - 9ms/step
# Epoch 221/250
#
# Epoch 221: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2378 - accuracy: 0.9347 - val_loss: 0.4453 - val_accuracy: 0.8383 - 224ms/epoch - 9ms/step
# Epoch 222/250
#
# Epoch 222: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2303 - accuracy: 0.9351 - val_loss: 0.4786 - val_accuracy: 0.8383 - 221ms/epoch - 9ms/step
# Epoch 223/250
#
# Epoch 223: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2308 - accuracy: 0.9325 - val_loss: 0.5623 - val_accuracy: 0.8008 - 229ms/epoch - 9ms/step
# Epoch 224/250
#
# Epoch 224: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2461 - accuracy: 0.9287 - val_loss: 0.4423 - val_accuracy: 0.8433 - 222ms/epoch - 9ms/step
# Epoch 225/250
#
# Epoch 225: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2380 - accuracy: 0.9328 - val_loss: 0.5113 - val_accuracy: 0.8225 - 228ms/epoch - 9ms/step
# Epoch 226/250
#
# Epoch 226: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2297 - accuracy: 0.9377 - val_loss: 0.4372 - val_accuracy: 0.8350 - 228ms/epoch - 9ms/step
# Epoch 227/250
#
# Epoch 227: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2448 - accuracy: 0.9293 - val_loss: 0.4706 - val_accuracy: 0.8275 - 218ms/epoch - 9ms/step
# Epoch 228/250
#
# Epoch 228: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2423 - accuracy: 0.9276 - val_loss: 0.4513 - val_accuracy: 0.8333 - 219ms/epoch - 9ms/step
# Epoch 229/250
#
# Epoch 229: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2658 - accuracy: 0.9168 - val_loss: 0.4810 - val_accuracy: 0.8400 - 219ms/epoch - 9ms/step
# Epoch 230/250
#
# Epoch 230: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2416 - accuracy: 0.9310 - val_loss: 0.4555 - val_accuracy: 0.8383 - 223ms/epoch - 9ms/step
# Epoch 231/250
#
# Epoch 231: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2301 - accuracy: 0.9358 - val_loss: 0.5256 - val_accuracy: 0.8192 - 216ms/epoch - 9ms/step
# Epoch 232/250
#
# Epoch 232: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2338 - accuracy: 0.9334 - val_loss: 0.4459 - val_accuracy: 0.8408 - 217ms/epoch - 9ms/step
# Epoch 233/250
#
# Epoch 233: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2441 - accuracy: 0.9284 - val_loss: 0.5315 - val_accuracy: 0.8158 - 215ms/epoch - 9ms/step
# Epoch 234/250
#
# Epoch 234: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2235 - accuracy: 0.9388 - val_loss: 0.4502 - val_accuracy: 0.8425 - 232ms/epoch - 9ms/step
# Epoch 235/250
#
# Epoch 235: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2466 - accuracy: 0.9277 - val_loss: 0.4297 - val_accuracy: 0.8417 - 218ms/epoch - 9ms/step
# Epoch 236/250
#
# Epoch 236: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2573 - accuracy: 0.9207 - val_loss: 0.5550 - val_accuracy: 0.8133 - 217ms/epoch - 9ms/step
# Epoch 237/250
#
# Epoch 237: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2300 - accuracy: 0.9358 - val_loss: 0.4614 - val_accuracy: 0.8408 - 217ms/epoch - 9ms/step
# Epoch 238/250
#
# Epoch 238: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2327 - accuracy: 0.9381 - val_loss: 0.5173 - val_accuracy: 0.8158 - 213ms/epoch - 9ms/step
# Epoch 239/250
#
# Epoch 239: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2609 - accuracy: 0.9181 - val_loss: 0.4442 - val_accuracy: 0.8458 - 209ms/epoch - 8ms/step
# Epoch 240/250
#
# Epoch 240: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2380 - accuracy: 0.9309 - val_loss: 0.4624 - val_accuracy: 0.8383 - 217ms/epoch - 9ms/step
# Epoch 241/250
#
# Epoch 241: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2229 - accuracy: 0.9394 - val_loss: 0.4818 - val_accuracy: 0.8325 - 218ms/epoch - 9ms/step
# Epoch 242/250
#
# Epoch 242: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2233 - accuracy: 0.9388 - val_loss: 0.5227 - val_accuracy: 0.8225 - 216ms/epoch - 9ms/step
# Epoch 243/250
#
# Epoch 243: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2294 - accuracy: 0.9343 - val_loss: 0.5001 - val_accuracy: 0.8300 - 215ms/epoch - 9ms/step
# Epoch 244/250
#
# Epoch 244: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2263 - accuracy: 0.9372 - val_loss: 0.6124 - val_accuracy: 0.7917 - 217ms/epoch - 9ms/step
# Epoch 245/250
#
# Epoch 245: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2390 - accuracy: 0.9283 - val_loss: 0.4530 - val_accuracy: 0.8425 - 223ms/epoch - 9ms/step
# Epoch 246/250
#
# Epoch 246: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2262 - accuracy: 0.9374 - val_loss: 0.4436 - val_accuracy: 0.8433 - 222ms/epoch - 9ms/step
# Epoch 247/250
#
# Epoch 247: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2326 - accuracy: 0.9352 - val_loss: 0.5609 - val_accuracy: 0.8142 - 212ms/epoch - 8ms/step
# Epoch 248/250
#
# Epoch 248: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2241 - accuracy: 0.9376 - val_loss: 0.5447 - val_accuracy: 0.8217 - 206ms/epoch - 8ms/step
# Epoch 249/250
#
# Epoch 249: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2299 - accuracy: 0.9355 - val_loss: 0.4412 - val_accuracy: 0.8433 - 218ms/epoch - 9ms/step
# Epoch 250/250
#
# Epoch 250: val_loss did not improve from 0.39744
# 25/25 - 0s - loss: 0.2185 - accuracy: 0.9409 - val_loss: 0.5111 - val_accuracy: 0.8283 - 213ms/epoch - 9ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Graficar la pérdida
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(loss, label='Pérdida en entrenamiento')
plt.plot(val_loss, label='Pérdida en pruebas')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()

# Graficar la precisión
plt.subplot(1, 2, 2)
plt.plot(accuracy, label='Precisión en entrenamiento')
plt.plot(val_accuracy, label='Precisión en pruebas')
plt.xlabel('Época')
plt.ylabel('Precisión')
plt.legend()

# Agregar un título central para la figura
plt.suptitle(f"Gráfico de Pérdidas y Presición"
             f" - Num parámetros {model.count_params()},\n"
             f"Épocas = {epochs}, Learning rate = {new_learning_rate}\n")
#              f"Precisión Ent {accuracy[len(accuracy)-1]:.6f},"
#              f" Precisión Prue {val_accuracy[len(val_accuracy)-1]:.6f}",fontsize=16)
plt.tight_layout()
plt.show()

# %%
#Carga Mejor modelo
from keras.models import load_model
# Cargar el modelo guardado en "best_model.h5"
model = load_model('best_model_checkpoint/best_model_epoch_128.h5')

# Evaluación en el conjunto test
_, accuracy = model.evaluate(testMFCCs, testLabels)
print(f'Accuracy: {accuracy}')
# Out:
# 38/38 [==============================] - 1s 7ms/step - loss: 0.3974 - accuracy: 0.8425
# Accuracy: 0.8424999713897705

# %%
# Evaluación en el conjunto train
_, accuracy = model.evaluate(trainMFCCs, trainLabels)
print(f'Accuracy: {accuracy}')
# Out:
#   6/375 [..............................] - ETA: 5s - loss: 0.2801 - accuracy: 0.9219
# 2024-04-09 04:41:07.789119: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 60480000 exceeds 10% of free system memory.
# 2024-04-09 04:41:07.854322: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 60480000 exceeds 10% of free system memory.
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2838 - accuracy: 0.9120
# Accuracy: 0.9120000004768372

# %% [markdown]
# ### Exporta Modelo

# %%
#Exporta el modelo
export_dir = 'saved_models/modelo_tesis_binario_Angry_finalv5'
# tf.saved_model.save(model, export_dir)
tf.keras.models.save_model(model, export_dir)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_models/modelo_tesis_binario_Angry_finalv5/assets
# INFO:tensorflow:Assets written to: saved_models/modelo_tesis_binario_Angry_finalv5/assets

# %% [markdown]
# ### Pruebas

# %%
#Define Umbral
umbral = 0.5
#Predice probabilidades de las clases (de 0 a 1)
predict = model.predict(evalMFCCs)
# Aplica el umbral para convertir las predicciones en 0 o 1
Label_predict = (predict > umbral).astype(int)
#Dimenciones de vector de etiquetas
print("Dimensiones de vector de etiquetas: ", Label_predict.shape)
# Out:
# 25/25 [==============================] - 0s 8ms/step
# Dimensiones de vector de etiquetas:  (800, 1)

# %%
#Calcula matriz de confusión
con_mat = confusion_matrix(evalLabels, Label_predict, labels=clases_vec)
#Convierte matriz en un pandas dataframe
#Rows =    Valores verdaderos
#Columns = Valores predichos
con_mat_df = pd.DataFrame(con_mat, index=emotion_vec, columns=emotion_vec)

# Crear un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(con_mat_df, annot=True, fmt='d', cmap='Blues')

plt.xlabel('Valores predichos', fontsize=14)
plt.ylabel('Valores verdaderos', fontsize=14)
plt.title('Matriz de Confusión', fontsize=16)
plt.show()

# %%
# Evaluación en el conjunto de validación
_, accuracy = model.evaluate(evalMFCCs, evalLabels)

print(f'Accuracy: {accuracy}')
# Out:
# 25/25 [==============================] - 0s 11ms/step - loss: 0.4988 - accuracy: 0.7850
# Accuracy: 0.7850000262260437

# %%
#Crea lista vacía de estadísticos
statistics = []

#Ciclo para calcular especificidad, recall, precision y f_score
for label in range(0,2):
    precision, recall, f_score, support = precision_recall_fscore_support(evalLabels==label,
                                           Label_predict==label)
    statistics.append([emotion_vec[label], recall[0], recall[1], precision[1], f_score[1]])

#Convierte resultados en dataframe y agrega columnas
statistics = pd.DataFrame(statistics, columns=["Emotion","Specificity", "Recall", "Precision", "F_Score"])
statistics
# Out:
#   Emotion  Specificity  Recall  Precision  F_Score
# 0   Other        0.785   0.785      0.785    0.785
# 1   Angry        0.785   0.785      0.785    0.785

# %%
# Supongamos que 'etiquetas_reales' son las etiquetas reales (0 o 1) y 'predicciones' son las predicciones del modelo.
# Asegúrate de tener predicciones continuas (no binarias) en 'predicciones'.

fpr, tpr, umbrales = roc_curve(evalLabels, predict)
area_bajo_curva = roc_auc_score(evalLabels, predict)

# Grafica la Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (AUC = {area_bajo_curva:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # TENSORFLOW LITE

# %% [markdown]
# ### Convierte Modelo

# %%
#Path del modelo
model_dir = 'saved_models/modelo_tesis_binario_Angry_finalv5'

# %%
#Convierte el modelo con tensorflow lite desde un modelo guardado
converter = tf.lite.TFLiteConverter.from_saved_model(model_dir)
#Guarda modelo en variable
tflite_model = converter.convert()
# Out:
# 2024-04-09 04:58:00.670833: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2024-04-09 04:58:00.670882: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# 2024-04-09 04:58:00.671390: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: saved_models/modelo_tesis_binario_Angry_finalv5
# 2024-04-09 04:58:00.678619: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2024-04-09 04:58:00.678639: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: saved_models/modelo_tesis_binario_Angry_finalv5
# 2024-04-09 04:58:00.693398: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# 2024-04-09 04:58:00.696122: I tensorflow/cc/saved_model/loader.cc:229] Restoring SavedModel bundle.
# 2024-04-09 04:58:00.737009: I tensorflow/cc/saved_model/loader.cc:213] Running initialization op on SavedModel bundle at path: saved_models/modelo_tesis_binario_Angry_finalv5
# 2024-04-09 04:58:00.744991: I tensorflow/cc/saved_model/loader.cc:305] SavedModel load for tags { serve }; Status: success: OK. Took 73606 microseconds.
# 2024-04-09 04:58:00.759672: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
#imprime tamaño del modelo en bytes
tflite_model_file = pathlib.Path('modelo_tesis_binario_Angry_finalv5.tflite')
#Escribe bytes del archivo
tflite_model_file.write_bytes(tflite_model)
# Out:
# 66608

# %% [markdown]
# ### Carga Modelo

# %%
# Load TFLite model and allocate tensors.
tflite_model_file = 'modelo_tesis_binario_Angry_finalv5.tflite'
interpreter = tf.lite.Interpreter(model_path=tflite_model_file)
interpreter.allocate_tensors()

#Obtiene los índices de entrada y salida
input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# Obtener todos los detalles del modelo
model_details = interpreter.get_tensor_details()

# Filtrar los detalles para obtener solo los relacionados con los parámetros
parameter_details = [detail for detail in model_details if 'weight' in detail['name'] or 'bias' in detail['name']]

# Calcular el número total de parámetros
total_parameters = sum(np.prod(detail['shape']) for detail in parameter_details)

print("Número total de parámetros:", total_parameters)
# Out:
# Número total de parámetros: 7200

# %% [markdown]
# ## Predicciones

# %% [markdown]
# ### Entrenamiento

# %%
#Agrega dimensión para que coincida con la entrada de la red
trainMFCCs = np.expand_dims(trainMFCCs, axis=-1)
trainMFCCs = trainMFCCs.astype(np.float32)

#Predicciones de entrenamiento
predictions = []
for mfcc in trainMFCCs:
    # Asegúrate de que 'mfcc' tenga la forma y tipo de datos correctos
    mfcc = np.expand_dims(mfcc, axis=0).astype(np.float32)
    
    # Establecer la entrada del modelo
    interpreter.set_tensor(input_index, mfcc)
    
    # Realizar la inferencia
    interpreter.invoke()
    
    # Obtener la salida del modelo
    output = interpreter.get_tensor(output_index)
    predictions.append(output)

# %%
predictions[0:10]
# Out:
# [array([[0.33874097]], dtype=float32),
#  array([[0.47152612]], dtype=float32),
#  array([[0.9241117]], dtype=float32),
#  array([[0.8521627]], dtype=float32),
#  array([[0.884357]], dtype=float32),
#  array([[0.8123409]], dtype=float32),
#  array([[0.8897024]], dtype=float32),
#  array([[0.2839109]], dtype=float32),
#  array([[0.9348944]], dtype=float32),
#  array([[0.95892054]], dtype=float32)]

# %%
umbral = 0.5
predictions = np.array(predictions).squeeze()  # Convertir la lista a un array
predicted_labels = (predictions > umbral).astype(int)  # Usar un umbral si es necesario

# Comparar con las etiquetas reales
accuracy = np.mean(predicted_labels == trainLabels)
print("Precisión del modelo:", accuracy)
# Out:
# Precisión del modelo: 0.9120833333333334

# %% [markdown]
# ### Prueba

# %%
#Agrega dimensión para que coincida con la entrada de la red
testMFCCs = np.expand_dims(testMFCCs, axis=-1)
testMFCCs = testMFCCs.astype(np.float32)

#Predicciones de entrenamiento
predictions = []
for mfcc in testMFCCs:
    # Asegúrate de que 'mfcc' tenga la forma y tipo de datos correctos
    mfcc = np.expand_dims(mfcc, axis=0).astype(np.float32)
    
    # Establecer la entrada del modelo
    interpreter.set_tensor(input_index, mfcc)
    
    # Realizar la inferencia
    interpreter.invoke()
    
    # Obtener la salida del modelo
    output = interpreter.get_tensor(output_index)
    predictions.append(output)

#Calcula precisión según umbral
umbral = 0.5
predictions = np.array(predictions).squeeze()  # Convertir la lista a un array
predicted_labels = (predictions > umbral).astype(int)  # Usar un umbral si es necesario

# Comparar con las etiquetas reales
accuracy = np.mean(predicted_labels == testLabels)
print("Precisión del modelo:", accuracy)
# Out:
# Precisión del modelo: 0.8425

# %% [markdown]
# ### Evaluación

# %%
#Agrega dimensión para que coincida con la entrada de la red
evalMFCCs = np.expand_dims(evalMFCCs, axis=-1)
evalMFCCs = evalMFCCs.astype(np.float32)

#Predicciones de entrenamiento
predictions = []
for mfcc in evalMFCCs:
    # Asegúrate de que 'mfcc' tenga la forma y tipo de datos correctos
    mfcc = np.expand_dims(mfcc, axis=0).astype(np.float32)
    
    # Establecer la entrada del modelo
    interpreter.set_tensor(input_index, mfcc)
    
    # Realizar la inferencia
    interpreter.invoke()
    
    # Obtener la salida del modelo
    output = interpreter.get_tensor(output_index)
    predictions.append(output)

#Calcula precisión según umbral
umbral = 0.5
predictions = np.array(predictions).squeeze()  # Convertir la lista a un array
predicted_labels = (predictions > umbral).astype(int)  # Usar un umbral si es necesario

# Comparar con las etiquetas reales
accuracy = np.mean(predicted_labels == evalLabels)
print("Precisión del modelo:", accuracy)
# Out:
# Precisión del modelo: 0.785

# %% [markdown]
# ### Matriz de confusión

# %%
#Predicciones de 0 y 1
predictions_bin = (predictions > umbral).astype(int)

#Vector de clases
clases_vec = [0,1]
emotion_vec = ["Other","Angry"]

#Calcula matriz de confusión
con_mat = confusion_matrix(evalLabels, predictions_bin, labels=clases_vec)
#Convierte matriz en un pandas dataframe
#Rows =    Valores verdaderos
#Columns = Valores predichos
con_mat_df = pd.DataFrame(con_mat, index=emotion_vec, columns=emotion_vec)

# Crear un mapa de calor
plt.figure(figsize=(8, 6))
sns.heatmap(con_mat_df, annot=True, fmt='d', cmap='Blues')

plt.xlabel('Valores predichos', fontsize=14)
plt.ylabel('Valores verdaderos', fontsize=14)
plt.title('Matriz de Confusión TFLite', fontsize=16)
plt.show()

# %% [markdown]
# ### Curva ROC

# %%
# Supongamos que 'etiquetas_reales' son las etiquetas reales (0 o 1) y 'predicciones' son las predicciones del modelo.
# Asegúrate de tener predicciones continuas (no binarias) en 'predicciones'.

fpr, tpr, umbrales = roc_curve(evalLabels, predictions)
area_bajo_curva = roc_auc_score(evalLabels, predictions)

# Grafica la Curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Curva ROC (AUC = {area_bajo_curva:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Verdaderos Positivos (TPR)')
plt.title('Curva ROC TFLite')
plt.legend(loc='lower right')
plt.show()
